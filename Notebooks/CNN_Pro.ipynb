# %%
import glob

wav_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/train_data/*.wav"))
csv_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/train_labels/*.csv"))

# %%
import time
import torch.optim as optim
import torch.utils.data as data
from Model.CNN_3L_pro import *
import os

# start_file = "../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2443.wav"
# start_index = wav_files.index(start_file) if start_file in wav_files else 0
# 
# wav_files = wav_files[start_index:]
# csv_files = csv_files[start_index:]
# 
# print(f"Bắt đầu train tiếp từ file: {wav_files[0]}")

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# Khởi tạo mô hình, hàm mất mát và optimizer
model = CNN_Pro().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

if os.path.exists("CNN_Pro2.pth"):       
    checkpoint = torch.load("CNN_Pro2.pth", map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# Huấn luyện từng file một
for wav_path, csv_path in zip(wav_files, csv_files):
    print(time.strftime("%H:%M:%S")+f"\nfile : {wav_path}")
    # Load dữ liệu
    X_train, y_train = load_wav_csv(wav_path, csv_path)
    # Tạo DataLoader
    dataset = MusicDataset(X_train, y_train)
    train_loader = data.DataLoader(dataset, batch_size=64, shuffle=False)

    for epoch in range(20):  # Giảm số epoch cho từng file
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device).float()
            
            optimizer.zero_grad()
            outputs = model(inputs)
             # BCEWithLogitsLoss yêu cầu labels dạng float
            loss = criterion(outputs, labels)  
            loss.backward()
            optimizer.step()
        
            running_loss += loss.item()
            # Chuyển đầu ra thành nhị phân (multi-label classification)
            predicted = (outputs > 0.5).float()
        
            correct += (predicted == labels).sum().item() / 128  # Chia 128 để chuẩn hóa
            total += labels.size(0)

        if epoch >= 19:
            print(f"Epoch {epoch+1}/20, Loss: {running_loss/len(train_loader):.4f}, "
              f"Accuracy: {100 * correct / total:.2f}%")

    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, "CNN_Pro2.pth")
    print(f"Updated checkpoint sau file {wav_path}")

print("done training !")
# Out:
# 21:49:56
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1727.wav
# Tổng số frame: 38507
# Epoch 20/20, Loss: 0.1087, Accuracy: 96.41%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1727.wav
# 21:51:54
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1728.wav
# Tổng số frame: 21632
# Epoch 20/20, Loss: 0.0625, Accuracy: 97.46%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1728.wav
# 21:52:57
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1729.wav
# Tổng số frame: 38287
# Epoch 20/20, Loss: 0.0873, Accuracy: 96.80%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1729.wav
# 21:54:56
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1730.wav
# Tổng số frame: 31744
# Epoch 20/20, Loss: 0.0864, Accuracy: 96.81%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1730.wav
# 21:58:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1733.wav
# Tổng số frame: 47030
# Epoch 20/20, Loss: 0.0479, Accuracy: 98.30%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1733.wav
# 22:01:26
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1734.wav
# Tổng số frame: 28047
# Epoch 20/20, Loss: 0.0354, Accuracy: 98.65%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1734.wav
# 22:03:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1735.wav
# Tổng số frame: 61579
# Epoch 20/20, Loss: 0.0535, Accuracy: 98.23%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1735.wav
# 22:11:20
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1739.wav
# Tổng số frame: 42244
# Epoch 20/20, Loss: 0.0628, Accuracy: 97.65%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1739.wav
# 22:14:39
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1742.wav
# Tổng số frame: 79633
# Epoch 20/20, Loss: 0.0626, Accuracy: 97.59%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1742.wav
# 22:19:38
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1749.wav
# Tổng số frame: 59981
# Epoch 20/20, Loss: 0.0471, Accuracy: 98.35%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1749.wav
# 22:22:49
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1750.wav
# Tổng số frame: 67543
# Epoch 20/20, Loss: 0.0545, Accuracy: 97.99%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1750.wav
# 22:27:03
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1751.wav
# Tổng số frame: 40971
# Epoch 20/20, Loss: 0.0421, Accuracy: 98.25%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1751.wav
# 22:29:36
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1752.wav
# Tổng số frame: 31242
# Epoch 20/20, Loss: 0.0401, Accuracy: 98.49%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1752.wav
# 22:31:19
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1755.wav
# Tổng số frame: 19794
# Epoch 20/20, Loss: 0.0480, Accuracy: 97.90%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1755.wav
# 22:32:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1756.wav
# Tổng số frame: 31998
# Epoch 20/20, Loss: 0.0432, Accuracy: 98.32%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1756.wav
# 22:34:08
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1757.wav
# Tổng số frame: 61207
# Epoch 20/20, Loss: 0.0531, Accuracy: 98.03%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1757.wav
# 22:37:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1758.wav
# Tổng số frame: 40345
# Epoch 20/20, Loss: 0.0500, Accuracy: 97.91%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1758.wav
# 22:39:36
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1760.wav
# Tổng số frame: 56467
# Epoch 20/20, Loss: 0.0417, Accuracy: 98.44%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1760.wav
# 22:42:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1763.wav
# Tổng số frame: 51708
# Epoch 20/20, Loss: 0.0460, Accuracy: 98.11%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1763.wav
# 22:45:37
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1764.wav
# Tổng số frame: 37749
# Epoch 20/20, Loss: 0.0374, Accuracy: 98.33%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1764.wav
# 22:47:32
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1765.wav
# Tổng số frame: 58278
# Epoch 20/20, Loss: 0.0621, Accuracy: 97.45%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1765.wav
# 22:50:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1766.wav
# Tổng số frame: 36811
# Epoch 20/20, Loss: 0.0398, Accuracy: 98.49%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1766.wav
# 22:52:26
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1768.wav
# Tổng số frame: 25054
# Epoch 20/20, Loss: 0.0398, Accuracy: 98.07%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1768.wav
# 22:53:46
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1771.wav
# Tổng số frame: 55760
# Epoch 20/20, Loss: 0.0446, Accuracy: 98.26%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1771.wav
# 22:56:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1772.wav
# Tổng số frame: 35958
# Epoch 20/20, Loss: 0.0364, Accuracy: 98.39%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1772.wav
# 22:58:37
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1773.wav
# Tổng số frame: 26476
# Epoch 20/20, Loss: 0.0285, Accuracy: 98.69%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1773.wav
# 23:00:02
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1775.wav
# Tổng số frame: 49804
# Epoch 20/20, Loss: 0.0421, Accuracy: 98.30%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1775.wav
# 23:02:43
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1776.wav
# Tổng số frame: 62542
# Epoch 20/20, Loss: 0.0497, Accuracy: 97.76%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1776.wav
# 23:05:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1777.wav
# Tổng số frame: 54221
# Epoch 20/20, Loss: 0.0422, Accuracy: 98.06%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1777.wav
# 23:08:43
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1788.wav
# Tổng số frame: 44203
# Epoch 20/20, Loss: 0.0425, Accuracy: 98.20%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1788.wav
# 23:10:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1789.wav
# Tổng số frame: 39736
# Epoch 20/20, Loss: 0.0374, Accuracy: 98.35%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1789.wav
# 23:13:04
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1790.wav
# Tổng số frame: 27895
# Epoch 20/20, Loss: 0.0306, Accuracy: 98.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1790.wav
# 23:14:31
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1791.wav
# Tổng số frame: 30279
# Epoch 20/20, Loss: 0.0327, Accuracy: 98.52%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1791.wav
# 23:16:05
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1792.wav
# Tổng số frame: 40723
# Epoch 20/20, Loss: 0.0393, Accuracy: 98.33%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1792.wav
# 23:18:18
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1793.wav
# Tổng số frame: 43489
# Epoch 20/20, Loss: 0.0345, Accuracy: 98.45%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1793.wav
# 23:20:36
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1805.wav
# Tổng số frame: 30731
# Epoch 20/20, Loss: 0.0385, Accuracy: 98.25%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1805.wav
# 23:22:14
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1807.wav
# Tổng số frame: 38280
# Epoch 20/20, Loss: 0.0313, Accuracy: 98.56%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1807.wav
# 23:24:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1811.wav
# Tổng số frame: 42150
# Epoch 20/20, Loss: 0.0435, Accuracy: 97.88%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1811.wav
# 23:26:31
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1812.wav
# Tổng số frame: 40147
# Epoch 20/20, Loss: 0.0344, Accuracy: 98.41%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1812.wav
# 23:28:39
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1813.wav
# Tổng số frame: 50990
# Epoch 20/20, Loss: 0.0327, Accuracy: 98.45%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1813.wav
# 23:31:24
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1817.wav
# Tổng số frame: 21565
# Epoch 20/20, Loss: 0.0395, Accuracy: 98.09%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1817.wav
# 23:32:32
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1818.wav
# Tổng số frame: 35096
# Epoch 20/20, Loss: 0.0398, Accuracy: 98.11%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1818.wav
# 23:34:24
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1822.wav
# Tổng số frame: 39672
# Epoch 20/20, Loss: 0.0368, Accuracy: 98.32%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1822.wav
# 23:36:29
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1824.wav
# Tổng số frame: 21791
# Epoch 20/20, Loss: 0.0262, Accuracy: 98.75%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1824.wav
# 23:37:37
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1828.wav
# Tổng số frame: 22845
# Epoch 20/20, Loss: 0.0370, Accuracy: 98.36%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1828.wav
# 23:38:48
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1829.wav
# Tổng số frame: 36291
# Epoch 20/20, Loss: 0.0440, Accuracy: 98.12%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1829.wav
# 23:40:39
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1835.wav
# Tổng số frame: 20404
# Epoch 20/20, Loss: 0.0461, Accuracy: 98.19%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1835.wav
# 23:41:41
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1859.wav
# Tổng số frame: 33829
# Epoch 20/20, Loss: 0.0371, Accuracy: 98.37%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1859.wav
# 23:43:23
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1872.wav
# Tổng số frame: 43882
# Epoch 20/20, Loss: 0.0524, Accuracy: 97.85%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1872.wav
# 23:45:36
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1873.wav
# Tổng số frame: 31579
# Epoch 20/20, Loss: 0.0529, Accuracy: 97.94%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1873.wav
# 23:47:11
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1876.wav
# Tổng số frame: 30704
# Epoch 20/20, Loss: 0.0513, Accuracy: 97.88%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1876.wav
# 23:48:44
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1893.wav
# Tổng số frame: 28067
# Epoch 20/20, Loss: 0.0486, Accuracy: 97.97%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1893.wav
# 23:50:09
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1916.wav
# Tổng số frame: 58142
# Epoch 20/20, Loss: 0.0519, Accuracy: 97.82%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1916.wav
# 23:53:04
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1918.wav
# Tổng số frame: 31624
# Epoch 20/20, Loss: 0.0418, Accuracy: 98.13%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1918.wav
# 23:54:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1919.wav
# Tổng số frame: 37408
# Epoch 20/20, Loss: 0.0516, Accuracy: 97.68%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1919.wav
# 23:56:32
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1922.wav
# Tổng số frame: 34628
# Epoch 20/20, Loss: 0.0380, Accuracy: 98.21%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1922.wav
# 23:58:16
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1923.wav
# Tổng số frame: 33865
# Epoch 20/20, Loss: 0.0527, Accuracy: 97.76%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1923.wav
# 23:59:58
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1931.wav
# Tổng số frame: 40612
# Epoch 20/20, Loss: 0.0332, Accuracy: 98.53%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1931.wav
# 00:02:01
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1932.wav
# Tổng số frame: 21539
# Epoch 20/20, Loss: 0.0399, Accuracy: 98.20%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1932.wav
# 00:03:05
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1933.wav
# Tổng số frame: 30287
# Epoch 20/20, Loss: 0.0384, Accuracy: 98.22%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1933.wav
# 00:04:36
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2075.wav
# Tổng số frame: 28339
# Epoch 20/20, Loss: 0.0388, Accuracy: 98.26%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2075.wav
# 00:06:00
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2076.wav
# Tổng số frame: 21319
# Epoch 20/20, Loss: 0.0271, Accuracy: 98.63%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2076.wav
# 00:07:04
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2077.wav
# Tổng số frame: 21544
# Epoch 20/20, Loss: 0.0301, Accuracy: 98.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2077.wav
# 00:08:09
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2078.wav
# Tổng số frame: 30664
# Epoch 20/20, Loss: 0.0385, Accuracy: 98.31%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2078.wav
# 00:09:41
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2079.wav
# Tổng số frame: 24006
# Epoch 20/20, Loss: 0.0323, Accuracy: 98.56%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2079.wav
# 00:10:53
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2080.wav
# Tổng số frame: 20147
# Epoch 20/20, Loss: 0.0303, Accuracy: 98.66%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2080.wav
# 00:11:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2081.wav
# Tổng số frame: 25833
# Epoch 20/20, Loss: 0.0332, Accuracy: 98.36%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2081.wav
# 00:13:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2082.wav
# Tổng số frame: 29442
# Epoch 20/20, Loss: 0.0295, Accuracy: 98.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2082.wav
# 00:14:41
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2083.wav
# Tổng số frame: 21103
# Epoch 20/20, Loss: 0.0282, Accuracy: 98.66%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2083.wav
# 00:15:45
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2104.wav
# Tổng số frame: 32017
# Epoch 20/20, Loss: 0.0401, Accuracy: 98.25%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2104.wav
# 00:17:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2105.wav
# Tổng số frame: 25133
# Epoch 20/20, Loss: 0.0312, Accuracy: 98.50%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2105.wav
# 00:18:38
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2112.wav
# Tổng số frame: 77306
# Epoch 20/20, Loss: 0.0689, Accuracy: 97.28%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2112.wav
# 00:22:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2113.wav
# Tổng số frame: 30394
# Epoch 20/20, Loss: 0.0432, Accuracy: 98.19%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2113.wav
# 00:24:01
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2114.wav
# Tổng số frame: 34718
# Epoch 20/20, Loss: 0.0604, Accuracy: 97.60%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2114.wav
# 00:25:46
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2116.wav
# Tổng số frame: 35393
# Epoch 20/20, Loss: 0.0638, Accuracy: 97.23%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2116.wav
# 00:27:32
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2117.wav
# Tổng số frame: 22919
# Epoch 20/20, Loss: 0.0491, Accuracy: 97.88%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2117.wav
# 00:28:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2118.wav
# Tổng số frame: 19994
# Epoch 20/20, Loss: 0.0574, Accuracy: 97.52%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2118.wav
# 00:29:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2119.wav
# Tổng số frame: 25378
# Epoch 20/20, Loss: 0.0431, Accuracy: 97.96%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2119.wav
# 00:30:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2127.wav
# Tổng số frame: 44672
# Epoch 20/20, Loss: 0.0631, Accuracy: 97.27%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2127.wav
# 00:33:14
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2131.wav
# Tổng số frame: 23648
# Epoch 20/20, Loss: 0.0649, Accuracy: 97.28%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2131.wav
# 00:34:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2138.wav
# Tổng số frame: 37031
# Epoch 20/20, Loss: 0.0405, Accuracy: 98.11%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2138.wav
# 00:36:16
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2140.wav
# Tổng số frame: 32864
# Epoch 20/20, Loss: 0.0490, Accuracy: 97.94%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2140.wav
# 00:37:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2147.wav
# Tổng số frame: 43223
# Epoch 20/20, Loss: 0.0577, Accuracy: 97.66%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2147.wav
# 00:40:08
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2148.wav
# Tổng số frame: 70858
# Epoch 20/20, Loss: 0.0765, Accuracy: 96.78%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2148.wav
# 00:43:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2149.wav
# Tổng số frame: 41027
# Epoch 20/20, Loss: 0.0598, Accuracy: 97.50%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2149.wav
# 00:45:44
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2150.wav
# Tổng số frame: 51602
# Epoch 20/20, Loss: 0.0753, Accuracy: 96.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2150.wav
# 00:48:20
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2151.wav
# Tổng số frame: 45939
# Epoch 20/20, Loss: 0.0520, Accuracy: 97.66%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2151.wav
# 00:50:38
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2154.wav
# Tổng số frame: 77023
# Epoch 20/20, Loss: 0.0589, Accuracy: 97.45%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2154.wav
# 00:54:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2155.wav
# Tổng số frame: 52207
# Epoch 20/20, Loss: 0.0564, Accuracy: 97.50%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2155.wav
# 00:57:06
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2156.wav
# Tổng số frame: 16540
# Epoch 20/20, Loss: 0.0376, Accuracy: 97.87%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2156.wav
# 00:57:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2157.wav
# Tổng số frame: 56937
# Epoch 20/20, Loss: 0.0546, Accuracy: 97.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2157.wav
# 01:00:46
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2158.wav
# Tổng số frame: 41529
# Epoch 20/20, Loss: 0.0505, Accuracy: 97.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2158.wav
# 01:02:50
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2159.wav
# Tổng số frame: 40183
# Epoch 20/20, Loss: 0.0530, Accuracy: 97.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2159.wav
# 01:04:51
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2160.wav
# Tổng số frame: 38500
# Epoch 20/20, Loss: 0.0666, Accuracy: 96.98%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2160.wav
# 01:06:47
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2161.wav
# Tổng số frame: 34212
# Epoch 20/20, Loss: 0.0507, Accuracy: 97.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2161.wav
# 01:08:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2166.wav
# Tổng số frame: 55065
# Epoch 20/20, Loss: 0.0634, Accuracy: 97.32%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2166.wav
# 01:11:18
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2167.wav
# Tổng số frame: 16664
# Epoch 20/20, Loss: 0.0435, Accuracy: 97.79%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2167.wav
# 01:12:09
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2168.wav
# Tổng số frame: 52779
# Epoch 20/20, Loss: 0.0566, Accuracy: 97.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2168.wav
# 01:14:49
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2169.wav
# Tổng số frame: 44726
# Epoch 20/20, Loss: 0.0652, Accuracy: 97.27%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2169.wav
# 01:17:04
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2177.wav
# Tổng số frame: 42278
# Epoch 20/20, Loss: 0.0451, Accuracy: 97.93%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2177.wav
# 01:19:12
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2178.wav
# Tổng số frame: 30598
# Epoch 20/20, Loss: 0.0283, Accuracy: 98.74%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2178.wav
# 01:20:44
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2179.wav
# Tổng số frame: 43502
# Epoch 20/20, Loss: 0.0400, Accuracy: 98.26%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2179.wav
# 01:22:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2180.wav
# Tổng số frame: 25297
# Epoch 20/20, Loss: 0.0425, Accuracy: 97.84%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2180.wav
# 01:24:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2186.wav
# Tổng số frame: 18466
# Epoch 20/20, Loss: 0.0137, Accuracy: 99.42%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2186.wav
# 01:25:08
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2194.wav
# Tổng số frame: 8623
# Epoch 20/20, Loss: 0.0210, Accuracy: 98.73%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2194.wav
# 01:25:35
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2195.wav
# Tổng số frame: 13361
# Epoch 20/20, Loss: 0.0328, Accuracy: 98.35%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2195.wav
# 01:26:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2196.wav
# Tổng số frame: 6501
# Epoch 20/20, Loss: 0.0259, Accuracy: 98.81%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2196.wav
# 01:26:34
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2198.wav
# Tổng số frame: 17049
# Epoch 20/20, Loss: 0.0407, Accuracy: 97.72%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2198.wav
# 01:27:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2200.wav
# Tổng số frame: 9779
# Epoch 20/20, Loss: 0.0341, Accuracy: 98.38%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2200.wav
# 01:27:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2201.wav
# Tổng số frame: 11566
# Epoch 20/20, Loss: 0.0345, Accuracy: 98.43%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2201.wav
# 01:28:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2202.wav
# Tổng số frame: 15609
# Epoch 20/20, Loss: 0.0170, Accuracy: 99.32%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2202.wav
# 01:29:18
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2203.wav
# Tổng số frame: 13453
# Epoch 20/20, Loss: 0.0107, Accuracy: 99.50%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2203.wav
# 01:29:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2204.wav
# Tổng số frame: 11406
# Epoch 20/20, Loss: 0.0111, Accuracy: 99.58%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2204.wav
# 01:30:34
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2207.wav
# Tổng số frame: 7720
# Epoch 20/20, Loss: 0.0317, Accuracy: 98.70%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2207.wav
# 01:30:58
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2208.wav
# Tổng số frame: 10405
# Epoch 20/20, Loss: 0.0355, Accuracy: 98.45%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2208.wav
# 01:31:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2209.wav
# Tổng số frame: 13849
# Epoch 20/20, Loss: 0.0467, Accuracy: 97.68%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2209.wav
# 01:32:11
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2210.wav
# Tổng số frame: 15361
# Epoch 20/20, Loss: 0.0436, Accuracy: 98.06%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2210.wav
# 01:32:58
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2211.wav
# Tổng số frame: 20433
# Epoch 20/20, Loss: 0.0415, Accuracy: 98.17%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2211.wav
# 01:34:00
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2212.wav
# Tổng số frame: 14905
# Epoch 20/20, Loss: 0.0397, Accuracy: 98.09%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2212.wav
# 01:34:45
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2213.wav
# Tổng số frame: 9991
# Epoch 20/20, Loss: 0.0300, Accuracy: 98.57%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2213.wav
# 01:35:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2214.wav
# Tổng số frame: 9246
# Epoch 20/20, Loss: 0.0242, Accuracy: 98.86%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2214.wav
# 01:35:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2215.wav
# Tổng số frame: 10029
# Epoch 20/20, Loss: 0.0425, Accuracy: 98.04%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2215.wav
# 01:36:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2217.wav
# Tổng số frame: 16045
# Epoch 20/20, Loss: 0.0195, Accuracy: 99.23%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2217.wav
# 01:37:01
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2218.wav
# Tổng số frame: 17224
# Epoch 20/20, Loss: 0.0111, Accuracy: 99.50%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2218.wav
# 01:37:53
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2219.wav
# Tổng số frame: 22480
# Epoch 20/20, Loss: 0.0086, Accuracy: 99.64%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2219.wav
# 01:39:03
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2220.wav
# Tổng số frame: 26013
# Epoch 20/20, Loss: 0.0130, Accuracy: 99.39%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2220.wav
# 01:40:21
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2221.wav
# Tổng số frame: 20773
# Epoch 20/20, Loss: 0.0079, Accuracy: 99.58%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2221.wav
# 01:41:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2222.wav
# Tổng số frame: 17402
# Epoch 20/20, Loss: 0.0099, Accuracy: 99.51%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2222.wav
# 01:42:16
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2224.wav
# Tổng số frame: 9372
# Epoch 20/20, Loss: 0.0386, Accuracy: 98.32%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2224.wav
# 01:42:44
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2225.wav
# Tổng số frame: 18406
# Epoch 20/20, Loss: 0.0552, Accuracy: 97.69%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2225.wav
# 01:43:39
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2227.wav
# Tổng số frame: 11149
# Epoch 20/20, Loss: 0.0388, Accuracy: 98.43%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2227.wav
# 01:44:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2228.wav
# Tổng số frame: 8449
# Epoch 20/20, Loss: 0.0237, Accuracy: 98.56%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2228.wav
# 01:44:39
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2229.wav
# Tổng số frame: 21067
# Epoch 20/20, Loss: 0.0448, Accuracy: 97.83%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2229.wav
# 01:45:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2230.wav
# Tổng số frame: 7286
# Epoch 20/20, Loss: 0.0358, Accuracy: 98.51%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2230.wav
# 01:46:04
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2231.wav
# Tổng số frame: 9961
# Epoch 20/20, Loss: 0.0330, Accuracy: 98.58%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2231.wav
# 01:46:35
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2232.wav
# Tổng số frame: 6769
# Epoch 20/20, Loss: 0.0363, Accuracy: 98.38%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2232.wav
# 01:46:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2234.wav
# Tổng số frame: 5518
# Epoch 20/20, Loss: 0.0296, Accuracy: 98.71%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2234.wav
# 01:47:12
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2237.wav
# Tổng số frame: 9406
# Epoch 20/20, Loss: 0.0438, Accuracy: 98.01%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2237.wav
# 01:47:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2238.wav
# Tổng số frame: 5169
# Epoch 20/20, Loss: 0.0337, Accuracy: 98.18%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2238.wav
# 01:47:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2239.wav
# Tổng số frame: 10339
# Epoch 20/20, Loss: 0.0413, Accuracy: 98.16%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2239.wav
# 01:48:26
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2240.wav
# Tổng số frame: 7975
# Epoch 20/20, Loss: 0.0305, Accuracy: 98.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2240.wav
# 01:48:50
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2241.wav
# Tổng số frame: 20863
# Epoch 20/20, Loss: 0.0175, Accuracy: 99.10%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2241.wav
# 01:49:53
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2242.wav
# Tổng số frame: 26938
# Epoch 20/20, Loss: 0.0221, Accuracy: 99.00%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2242.wav
# 01:51:14
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2243.wav
# Tổng số frame: 16707
# Epoch 20/20, Loss: 0.0129, Accuracy: 99.29%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2243.wav
# 01:52:05
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2244.wav
# Tổng số frame: 18464
# Epoch 20/20, Loss: 0.0118, Accuracy: 99.48%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2244.wav
# 01:53:00
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2247.wav
# Tổng số frame: 6998
# Epoch 20/20, Loss: 0.0451, Accuracy: 98.26%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2247.wav
# 01:53:21
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2248.wav
# Tổng số frame: 9014
# Epoch 20/20, Loss: 0.0400, Accuracy: 98.06%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2248.wav
# 01:53:48
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2282.wav
# Tổng số frame: 26983
# Epoch 20/20, Loss: 0.0542, Accuracy: 97.70%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2282.wav
# 01:55:10
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2283.wav
# Tổng số frame: 16547
# Epoch 20/20, Loss: 0.0410, Accuracy: 97.96%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2283.wav
# 01:56:00
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2284.wav
# Tổng số frame: 19591
# Epoch 20/20, Loss: 0.0438, Accuracy: 98.15%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2284.wav
# 01:56:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2285.wav
# Tổng số frame: 19463
# Epoch 20/20, Loss: 0.0403, Accuracy: 98.32%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2285.wav
# 01:57:57
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2288.wav
# Tổng số frame: 16516
# Epoch 20/20, Loss: 0.0118, Accuracy: 99.38%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2288.wav
# 01:58:47
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2289.wav
# Tổng số frame: 17517
# Epoch 20/20, Loss: 0.0116, Accuracy: 99.47%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2289.wav
# 01:59:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2292.wav
# Tổng số frame: 7867
# Epoch 20/20, Loss: 0.0438, Accuracy: 98.20%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2292.wav
# 02:00:04
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2293.wav
# Tổng số frame: 26715
# Epoch 20/20, Loss: 0.0114, Accuracy: 99.57%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2293.wav
# 02:01:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2294.wav
# Tổng số frame: 19677
# Epoch 20/20, Loss: 0.0086, Accuracy: 99.65%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2294.wav
# 02:02:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2295.wav
# Tổng số frame: 22348
# Epoch 20/20, Loss: 0.0078, Accuracy: 99.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2295.wav
# 02:03:32
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2296.wav
# Tổng số frame: 25144
# Epoch 20/20, Loss: 0.0128, Accuracy: 99.40%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2296.wav
# 02:04:48
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2297.wav
# Tổng số frame: 28792
# Epoch 20/20, Loss: 0.0075, Accuracy: 99.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2297.wav
# 02:06:14
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2300.wav
# Tổng số frame: 20516
# Epoch 20/20, Loss: 0.0523, Accuracy: 97.79%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2300.wav
# 02:07:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2302.wav
# Tổng số frame: 9331
# Epoch 20/20, Loss: 0.0433, Accuracy: 98.05%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2302.wav
# 02:07:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2304.wav
# Tổng số frame: 16914
# Epoch 20/20, Loss: 0.0389, Accuracy: 98.13%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2304.wav
# 02:08:34
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2305.wav
# Tổng số frame: 5612
# Epoch 20/20, Loss: 0.0297, Accuracy: 98.63%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2305.wav
# 02:08:51
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2307.wav
# Tổng số frame: 11818
# Epoch 20/20, Loss: 0.0449, Accuracy: 98.13%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2307.wav
# 02:09:27
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2308.wav
# Tổng số frame: 10495
# Epoch 20/20, Loss: 0.0429, Accuracy: 98.21%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2308.wav
# 02:09:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2310.wav
# Tổng số frame: 4759
# Epoch 20/20, Loss: 0.0243, Accuracy: 98.75%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2310.wav
# 02:10:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2313.wav
# Tổng số frame: 51152
# Epoch 20/20, Loss: 0.0564, Accuracy: 97.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2313.wav
# 02:12:47
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2314.wav
# Tổng số frame: 48934
# Epoch 20/20, Loss: 0.0386, Accuracy: 98.30%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2314.wav
# 02:15:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2315.wav
# Tổng số frame: 92080
# Epoch 20/20, Loss: 0.0421, Accuracy: 98.08%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2315.wav
# 02:19:53
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2318.wav
# Tổng số frame: 55290
# Epoch 20/20, Loss: 0.0442, Accuracy: 98.13%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2318.wav
# 02:22:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2319.wav
# Tổng số frame: 53481
# Epoch 20/20, Loss: 0.0380, Accuracy: 98.19%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2319.wav
# 02:25:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2320.wav
# Tổng số frame: 19186
# Epoch 20/20, Loss: 0.0284, Accuracy: 98.63%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2320.wav
# 02:26:20
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2322.wav
# Tổng số frame: 55641
# Epoch 20/20, Loss: 0.0493, Accuracy: 97.85%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2322.wav
# 02:29:07
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2325.wav
# Tổng số frame: 47489
# Epoch 20/20, Loss: 0.0396, Accuracy: 98.19%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2325.wav
# 02:31:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2330.wav
# Tổng số frame: 45838
# Epoch 20/20, Loss: 0.0397, Accuracy: 98.19%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2330.wav
# 02:33:47
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2334.wav
# Tổng số frame: 35274
# Epoch 20/20, Loss: 0.0415, Accuracy: 98.20%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2334.wav
# 02:35:34
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2335.wav
# Tổng số frame: 36392
# Epoch 20/20, Loss: 0.0376, Accuracy: 98.30%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2335.wav
# 02:37:24
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2336.wav
# Tổng số frame: 17040
# Epoch 20/20, Loss: 0.0491, Accuracy: 97.76%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2336.wav
# 02:38:16
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2341.wav
# Tổng số frame: 39697
# Epoch 20/20, Loss: 0.0347, Accuracy: 98.44%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2341.wav
# 02:40:16
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2342.wav
# Tổng số frame: 16563
# Epoch 20/20, Loss: 0.0458, Accuracy: 97.77%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2342.wav
# 02:41:05
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2343.wav
# Tổng số frame: 28672
# Epoch 20/20, Loss: 0.0473, Accuracy: 97.90%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2343.wav
# 02:42:31
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2345.wav
# Tổng số frame: 38158
# Epoch 20/20, Loss: 0.0566, Accuracy: 97.54%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2345.wav
# 02:44:27
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2346.wav
# Tổng số frame: 28933
# Epoch 20/20, Loss: 0.0361, Accuracy: 98.12%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2346.wav
# 02:45:53
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2348.wav
# Tổng số frame: 42526
# Epoch 20/20, Loss: 0.0506, Accuracy: 97.69%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2348.wav
# 02:48:01
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2350.wav
# Tổng số frame: 23794
# Epoch 20/20, Loss: 0.0447, Accuracy: 97.99%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2350.wav
# 02:49:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2357.wav
# Tổng số frame: 30808
# Epoch 20/20, Loss: 0.0388, Accuracy: 98.27%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2357.wav
# 02:50:46
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2358.wav
# Tổng số frame: 11881
# Epoch 20/20, Loss: 0.0282, Accuracy: 98.72%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2358.wav
# 02:51:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2359.wav
# Tổng số frame: 26251
# Epoch 20/20, Loss: 0.0360, Accuracy: 98.41%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2359.wav
# 02:52:41
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2364.wav
# Tổng số frame: 25581
# Epoch 20/20, Loss: 0.0343, Accuracy: 98.43%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2364.wav
# 02:53:57
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2365.wav
# Tổng số frame: 34657
# Epoch 20/20, Loss: 0.0655, Accuracy: 97.39%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2365.wav
# 02:55:43
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2366.wav
# Tổng số frame: 81066
# Epoch 20/20, Loss: 0.0550, Accuracy: 97.63%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2366.wav
# 02:59:47
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2368.wav
# Tổng số frame: 37438
# Epoch 20/20, Loss: 0.0487, Accuracy: 97.79%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2368.wav
# 03:01:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2371.wav
# Tổng số frame: 17681
# Epoch 20/20, Loss: 0.0363, Accuracy: 98.22%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2371.wav
# 03:02:33
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2372.wav
# Tổng số frame: 19688
# Epoch 20/20, Loss: 0.0361, Accuracy: 98.49%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2372.wav
# 03:03:32
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2373.wav
# Tổng số frame: 27444
# Epoch 20/20, Loss: 0.0284, Accuracy: 98.75%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2373.wav
# 03:04:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2374.wav
# Tổng số frame: 18651
# Epoch 20/20, Loss: 0.0285, Accuracy: 98.68%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2374.wav
# 03:05:52
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2376.wav
# Tổng số frame: 50070
# Epoch 20/20, Loss: 0.0390, Accuracy: 98.20%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2376.wav
# 03:08:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2377.wav
# Tổng số frame: 66137
# Epoch 20/20, Loss: 0.0385, Accuracy: 98.21%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2377.wav
# 03:11:41
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2379.wav
# Tổng số frame: 28792
# Epoch 20/20, Loss: 0.0360, Accuracy: 98.41%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2379.wav
# 03:13:07
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2381.wav
# Tổng số frame: 48283
# Epoch 20/20, Loss: 0.0419, Accuracy: 98.21%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2381.wav
# 03:15:33
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2383.wav
# Tổng số frame: 33060
# Epoch 20/20, Loss: 0.0338, Accuracy: 98.38%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2383.wav
# 03:17:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2384.wav
# Tổng số frame: 18336
# Epoch 20/20, Loss: 0.0409, Accuracy: 98.15%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2384.wav
# 03:18:09
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2388.wav
# Tổng số frame: 40800
# Epoch 20/20, Loss: 0.0379, Accuracy: 98.34%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2388.wav
# 03:20:13
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2389.wav
# Tổng số frame: 38732
# Epoch 20/20, Loss: 0.0312, Accuracy: 98.58%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2389.wav
# 03:22:09
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2390.wav
# ...
# 04:46:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2501.wav
# Tổng số frame: 31627
# Epoch 20/20, Loss: 0.0373, Accuracy: 98.29%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2501.wav
# 04:47:50
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2502.wav
# Tổng số frame: 23061
# Epoch 20/20, Loss: 0.0329, Accuracy: 98.49%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2502.wav
# 04:48:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2504.wav
# Tổng số frame: 39659
# Epoch 20/20, Loss: 0.0322, Accuracy: 98.48%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2504.wav
# 04:51:00
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2505.wav
# Tổng số frame: 42150
# Epoch 20/20, Loss: 0.0246, Accuracy: 98.85%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2505.wav
# 04:53:06
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2506.wav
# Tổng số frame: 16189
# Epoch 20/20, Loss: 0.0279, Accuracy: 98.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2506.wav
# 04:53:55
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2507.wav
# Tổng số frame: 18761
# Epoch 20/20, Loss: 0.0290, Accuracy: 98.62%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2507.wav
# 04:54:52
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2509.wav
# Tổng số frame: 41720
# Epoch 20/20, Loss: 0.0262, Accuracy: 98.74%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2509.wav
# 04:56:57
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2510.wav
# Tổng số frame: 38941
# Epoch 20/20, Loss: 0.0305, Accuracy: 98.60%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2510.wav
# 04:58:54
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2512.wav
# Tổng số frame: 36480
# Epoch 20/20, Loss: 0.0272, Accuracy: 98.71%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2512.wav
# 05:00:44
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2514.wav
# Tổng số frame: 34966
# Epoch 20/20, Loss: 0.0278, Accuracy: 98.71%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2514.wav
# 05:02:29
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2516.wav
# Tổng số frame: 33413
# Epoch 20/20, Loss: 0.0255, Accuracy: 98.72%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2516.wav
# 05:04:09
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2521.wav
# Tổng số frame: 64770
# Epoch 20/20, Loss: 0.0379, Accuracy: 98.29%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2521.wav
# 05:07:24
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2522.wav
# Tổng số frame: 31349
# Epoch 20/20, Loss: 0.0253, Accuracy: 98.80%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2522.wav
# 05:08:58
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2523.wav
# Tổng số frame: 48116
# Epoch 20/20, Loss: 0.0324, Accuracy: 98.51%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2523.wav
# 05:11:23
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2527.wav
# Tổng số frame: 33258
# Epoch 20/20, Loss: 0.0244, Accuracy: 98.75%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2527.wav
# 05:13:02
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2528.wav
# Tổng số frame: 39943
# Epoch 20/20, Loss: 0.0305, Accuracy: 98.64%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2528.wav
# 05:15:03
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2529.wav
# Tổng số frame: 23731
# Epoch 20/20, Loss: 0.0307, Accuracy: 98.61%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2529.wav
# 05:16:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2530.wav
# Tổng số frame: 48412
# Epoch 20/20, Loss: 0.0351, Accuracy: 98.45%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2530.wav
# 05:18:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2531.wav
# Tổng số frame: 85453
# Epoch 20/20, Loss: 0.0344, Accuracy: 98.39%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2531.wav
# 05:22:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2532.wav
# Tổng số frame: 47237
# Epoch 20/20, Loss: 0.0335, Accuracy: 98.48%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2532.wav
# 05:25:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2533.wav
# Tổng số frame: 91987
# Epoch 20/20, Loss: 0.0323, Accuracy: 98.51%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2533.wav
# 05:29:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2537.wav
# Tổng số frame: 24715
# Epoch 20/20, Loss: 0.0136, Accuracy: 99.25%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2537.wav
# 05:31:14
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2538.wav
# Tổng số frame: 18275
# Epoch 20/20, Loss: 0.0138, Accuracy: 99.36%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2538.wav
# 05:32:09
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2540.wav
# Tổng số frame: 22699
# Epoch 20/20, Loss: 0.0444, Accuracy: 97.93%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2540.wav
# 05:33:17
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2542.wav
# Tổng số frame: 56073
# Epoch 20/20, Loss: 0.0378, Accuracy: 98.28%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2542.wav
# 05:36:07
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2550.wav
# Tổng số frame: 15530
# Epoch 20/20, Loss: 0.0299, Accuracy: 98.65%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2550.wav
# 05:36:54
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2555.wav
# Tổng số frame: 19270
# Epoch 20/20, Loss: 0.0398, Accuracy: 98.18%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2555.wav
# 05:37:51
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2557.wav
# Tổng số frame: 65656
# Epoch 20/20, Loss: 0.0328, Accuracy: 98.50%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2557.wav
# 05:41:12
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2560.wav
# Tổng số frame: 32684
# Epoch 20/20, Loss: 0.0257, Accuracy: 98.81%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2560.wav
# 05:42:50
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2562.wav
# Tổng số frame: 28477
# Epoch 20/20, Loss: 0.0298, Accuracy: 98.64%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2562.wav
# 05:44:15
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2564.wav
# Tổng số frame: 47712
# Epoch 20/20, Loss: 0.0269, Accuracy: 98.73%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2564.wav
# 05:46:40
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2566.wav
# Tổng số frame: 34907
# Epoch 20/20, Loss: 0.0331, Accuracy: 98.46%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2566.wav
# 05:48:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2567.wav
# Tổng số frame: 33348
# Epoch 20/20, Loss: 0.0268, Accuracy: 98.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2567.wav
# 05:50:05
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2568.wav
# Tổng số frame: 41180
# Epoch 20/20, Loss: 0.0270, Accuracy: 98.59%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2568.wav
# 05:52:10
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2570.wav
# Tổng số frame: 43671
# Epoch 20/20, Loss: 0.0288, Accuracy: 98.66%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2570.wav
# 05:54:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2571.wav
# Tổng số frame: 46515
# Epoch 20/20, Loss: 0.0307, Accuracy: 98.52%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2571.wav
# 05:56:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2572.wav
# Tổng số frame: 17317
# Epoch 20/20, Loss: 0.0140, Accuracy: 99.27%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2572.wav
# 05:57:34
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2573.wav
# Tổng số frame: 29296
# Epoch 20/20, Loss: 0.0272, Accuracy: 98.65%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2573.wav
# 05:59:02
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2575.wav
# Tổng số frame: 26175
# Epoch 20/20, Loss: 0.0270, Accuracy: 98.58%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2575.wav
# 06:00:21
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2576.wav
# Tổng số frame: 24094
# Epoch 20/20, Loss: 0.0236, Accuracy: 98.88%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2576.wav
# 06:01:34
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2581.wav
# Tổng số frame: 29779
# Epoch 20/20, Loss: 0.0225, Accuracy: 98.83%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2581.wav
# 06:03:04
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2582.wav
# Tổng số frame: 34322
# Epoch 20/20, Loss: 0.0218, Accuracy: 98.98%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2582.wav
# 06:04:47
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2586.wav
# Tổng số frame: 36986
# Epoch 20/20, Loss: 0.0432, Accuracy: 98.05%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2586.wav
# 06:06:38
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2588.wav
# Tổng số frame: 45037
# Epoch 20/20, Loss: 0.0276, Accuracy: 98.67%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2588.wav
# 06:08:54
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2590.wav
# Tổng số frame: 33656
# Epoch 20/20, Loss: 0.0198, Accuracy: 99.00%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2590.wav
# 06:10:35
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2591.wav
# Tổng số frame: 15460
# Epoch 20/20, Loss: 0.0243, Accuracy: 98.89%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2591.wav
# 06:11:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2593.wav
# Tổng số frame: 44177
# Epoch 20/20, Loss: 0.0220, Accuracy: 98.96%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2593.wav
# 06:13:35
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2594.wav
# Tổng số frame: 27505
# Epoch 20/20, Loss: 0.0182, Accuracy: 99.13%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2594.wav
# 06:14:59
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2595.wav
# Tổng số frame: 26503
# Epoch 20/20, Loss: 0.0178, Accuracy: 99.16%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2595.wav
# 06:16:21
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2596.wav
# Tổng số frame: 28063
# Epoch 20/20, Loss: 0.0205, Accuracy: 99.03%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2596.wav
# 06:17:47
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2603.wav
# Tổng số frame: 36025
# Epoch 20/20, Loss: 0.0332, Accuracy: 98.47%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2603.wav
# 06:19:35
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2607.wav
# Tổng số frame: 58053
# Epoch 20/20, Loss: 0.0252, Accuracy: 98.79%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2607.wav
# 06:22:30
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2608.wav
# Tổng số frame: 33638
# Epoch 20/20, Loss: 0.0276, Accuracy: 98.61%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2608.wav
# 06:24:11
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2611.wav
# Tổng số frame: 48515
# Epoch 20/20, Loss: 0.0262, Accuracy: 98.76%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2611.wav
# 06:26:37
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2614.wav
# Tổng số frame: 54709
# Epoch 20/20, Loss: 0.0223, Accuracy: 98.90%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2614.wav
# 06:29:22
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2618.wav
# Tổng số frame: 31368
# Epoch 20/20, Loss: 0.0215, Accuracy: 98.98%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2618.wav
# 06:30:58
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2619.wav
# Tổng số frame: 20543
# Epoch 20/20, Loss: 0.0210, Accuracy: 99.06%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2619.wav
# 06:32:00
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2620.wav
# Tổng số frame: 13771
# Epoch 20/20, Loss: 0.0241, Accuracy: 98.84%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2620.wav
# 06:32:41
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2621.wav
# Tổng số frame: 55873
# Epoch 20/20, Loss: 0.0308, Accuracy: 98.53%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2621.wav
# 06:35:29
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2622.wav
# Tổng số frame: 43691
# Epoch 20/20, Loss: 0.0277, Accuracy: 98.71%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2622.wav
# 06:37:42
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2626.wav
# Tổng số frame: 51159
# Epoch 20/20, Loss: 0.0371, Accuracy: 98.23%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2626.wav
# 06:40:19
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2627.wav
# Tổng số frame: 27824
# Epoch 20/20, Loss: 0.0388, Accuracy: 98.11%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2627.wav
# 06:41:43
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2629.wav
# Tổng số frame: 44614
# Epoch 20/20, Loss: 0.0427, Accuracy: 97.99%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2629.wav
# 06:43:58
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2632.wav
# Tổng số frame: 29449
# Epoch 20/20, Loss: 0.0183, Accuracy: 99.04%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2632.wav
# 06:45:27
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2633.wav
# Tổng số frame: 19553
# Epoch 20/20, Loss: 0.0161, Accuracy: 99.27%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2633.wav
# 06:46:25
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2659.wav
# Tổng số frame: 9331
# Epoch 20/20, Loss: 0.0043, Accuracy: 99.80%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2659.wav
# 06:46:53
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2677.wav
# Tổng số frame: 38352
# Epoch 20/20, Loss: 0.0335, Accuracy: 98.45%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2677.wav
# 06:48:48
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2678.wav
# Tổng số frame: 40687
# Epoch 20/20, Loss: 0.0220, Accuracy: 98.94%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2678.wav
# done training !

# %%
import glob
import torch

test_wav_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_data/*.wav"))
test_csv_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_labels/*.csv"))

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

model = CNN_Pro().to(device)
checkpoint = torch.load("../Trained/CNN_Pro2.pth", map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()  # Đưa model vào chế độ đánh giá

import numpy as np
import torch.utils.data as data

total_correct = 0
total_samples = 0



for wav_path, csv_path in zip(test_wav_files, test_csv_files):
    print(f"\nĐang test file: {wav_path}")

    X_test, y_test = load_wav_csv(wav_path, csv_path)

    test_dataset = MusicDataset(X_test, y_test)
    test_loader = data.DataLoader(test_dataset, batch_size=64, shuffle=False)

    correct = 0
    total = 0

    with torch.no_grad():  # Không tính gradient khi test
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).float()

            outputs = model(inputs)
            predicted = (outputs > 0.5).float()  # Chuyển thành 0 hoặc 1
            
            correct += (predicted == labels).sum().item() / 128  # Chia 128 để chuẩn hóa
            total += labels.size(0)

    accuracy = 100 * correct / total
    print(f"Accuracy: {accuracy:.2f}%")

    total_correct += correct
    total_samples += total

print(f"\n🔥 Accuracy chung trên tập test: {100 * total_correct / total_samples:.2f}%")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_21446/4174036012.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("../Trained/CNN_Pro2.pth", map_location=device)
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/1759.wav
# Tổng số frame: 16768
# Accuracy: 98.05%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/1819.wav
# Tổng số frame: 15287
# Accuracy: 97.76%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2106.wav
# Tổng số frame: 19523
# Accuracy: 97.99%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2191.wav
# Tổng số frame: 8859
# Accuracy: 99.21%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2298.wav
# Tổng số frame: 13224
# Accuracy: 99.26%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2303.wav
# Tổng số frame: 7981
# Accuracy: 98.27%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2382.wav
# Tổng số frame: 10164
# Accuracy: 98.37%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2416.wav
# Tổng số frame: 11984
# Accuracy: 98.51%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2556.wav
# Tổng số frame: 13046
# Accuracy: 97.94%
#
# Đang test file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2628.wav
# Tổng số frame: 10740
# Accuracy: 97.80%
#
# 🔥 Accuracy chung trên tập test: 98.26%

# %%
import torch
import numpy as np
import librosa
import librosa.display

def midi_to_note(midi_note):
    return librosa.midi_to_note(midi_note)

def predict_notes(wav_path, model, device="cpu", sr=44100, hop_length=512, window_size=128, step=21):
    print(f"\n🔍 Đang dự đoán file: {wav_path}")

    # Load file WAV
    y, sr = librosa.load(wav_path, sr=sr)
    
    # Tạo Mel spectrogram
    mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, hop_length=hop_length)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

    # Chia thành các cửa sổ (windows)
    X_windows = []
    timestamps = []
    frame_duration = step * hop_length / sr  # Khoảng thời gian của mỗi frame

    for i in range(0, mel_spec_db.shape[1] - window_size, step):
        X_windows.append(mel_spec_db[:, i:i + window_size])
        timestamps.append(i * hop_length / sr)  # Thời gian tính bằng giây
    
    # Chuyển thành tensor
    X_windows = torch.tensor(np.array(X_windows), dtype=torch.float32).unsqueeze(1).to(device)

    batch_size = 32  # Giảm batch size để tránh hết RAM
    num_batches = len(X_windows) // batch_size + 1
    predictions = []
    
    with torch.no_grad():
        for i in range(num_batches):
            batch = X_windows[i * batch_size:(i + 1) * batch_size]
            if batch.shape[0] == 0:
                continue  # Bỏ qua batch rỗng cuối cùng
            outputs = model(batch)
            predictions.append((outputs > 0.5).float().cpu().numpy())
    
    predictions = np.concatenate(predictions, axis=0)  # Ghép lại thành một mảng
    # Xử lý duration của nốt nhạc
    active_notes = {}  # Lưu trạng thái nốt đang được phát
    note_events = []  # Lưu kết quả cuối cùng

    for i, (time, pred) in enumerate(zip(timestamps, predictions)):
        notes = np.where(pred == 1)[0]  # Lấy danh sách các nốt có giá trị 1

        new_active_notes = set(notes)  # Chuyển sang tập hợp để dễ kiểm tra
        
        # Kiểm tra nốt nào vẫn tiếp tục hoặc mới bắt đầu
        for note in new_active_notes:
            if note not in active_notes:
                active_notes[note] = {"start": time, "duration": frame_duration}
            else:
                active_notes[note]["duration"] += frame_duration

        # Kiểm tra nốt nào đã kết thúc
        ended_notes = set(active_notes.keys()) - new_active_notes
        for note in ended_notes:
            note_events.append({
                "note": midi_to_note(note),  # Chuyển đổi MIDI thành tên nốt
                "duration": active_notes[note]["duration"]
            })
            del active_notes[note]

    # Ghi nhận các nốt còn sót lại (kết thúc ở frame cuối)
    for note, info in active_notes.items():
        note_events.append({
            "note": midi_to_note(note),  # Chuyển đổi MIDI thành tên nốt
            "duration": info["duration"]
        })

    return note_events  # Trả về danh sách nốt nhạc

import gc
import torch

gc.collect()
torch.mps.empty_cache()  # Dọn bộ nhớ GPU trên Mac M1/M2
# Ví dụ sử dụng:
wav_path = "../Data/MusicNet_Dataset/musicnet/musicnet/test_data/1819.wav"
notes = predict_notes(wav_path, model, device=device)

print(notes)
# Out:
# 🔍 Đang dự đoán file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/1819.wav
# [{'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'A♯4', 'duration': 0.4876190476190476}, {'note': 'D4', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.7314285714285714}, {'note': 'A♯4', 'duration': 0.4876190476190476}, {'note': 'G5', 'duration': 0.4876190476190476}, {'note': 'D♯5', 'duration': 0.7314285714285714}, {'note': 'D♯4', 'duration': 0.2438095238095238}, {'note': 'G5', 'duration': 0.2438095238095238}, {'note': 'C5', 'duration': 0.4876190476190476}, {'note': 'D♯5', 'duration': 0.2438095238095238}, {'note': 'D5', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.2438095238095238}, {'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'C5', 'duration': 0.9752380952380952}, {'note': 'F5', 'duration': 0.4876190476190476}, {'note': 'A♯4', 'duration': 0.4876190476190476}, {'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'A♯4', 'duration': 0.4876190476190476}, {'note': 'F5', 'duration': 0.7314285714285714}, {'note': 'A♯4', 'duration': 0.4876190476190476}, {'note': 'G5', 'duration': 0.4876190476190476}, {'note': 'D♯4', 'duration': 0.2438095238095238}, {'note': 'D♯5', 'duration': 0.7314285714285714}, {'note': 'G3', 'duration': 0.2438095238095238}, {'note': 'D♯4', 'duration': 0.2438095238095238}, {'note': 'G5', 'duration': 0.2438095238095238}, {'note': 'C5', 'duration': 0.2438095238095238}, {'note': 'D♯5', 'duration': 0.4876190476190476}, {'note': 'D5', 'duration': 0.2438095238095238}, {'note': 'D5', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.2438095238095238}, {'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'C5', 'duration': 0.4876190476190476}, {'note': 'F5', 'duration': 0.7314285714285714}, {'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'D4', 'duration': 0.2438095238095238}, {'note': 'G4', 'duration': 0.4876190476190476}, {'note': 'G3', 'duration': 0.2438095238095238}, {'note': 'D5', 'duration': 0.2438095238095238}, {'note': 'G5', 'duration': 0.2438095238095238}, {'note': 'G3', 'duration': 0.2438095238095238}, {'note': 'D♯5', 'duration': 0.2438095238095238}, {'note': 'B3', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.2438095238095238}, {'note': 'D5', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.7314285714285714}, {'note': 'A♯3', 'duration': 0.9752380952380952}, {'note': 'D5', 'duration': 1.2190476190476192}, {'note': 'G3', 'duration': 0.2438095238095238}, {'note': 'A♯3', 'duration': 0.2438095238095238}, {'note': 'G4', 'duration': 0.4876190476190476}, {'note': 'G4', 'duration': 0.4876190476190476}, {'note': 'F4', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.2438095238095238}, {'note': 'G♯3', 'duration': 0.7314285714285714}, {'note': 'F5', 'duration': 0.2438095238095238}, {'note': 'G♯3', 'duration': 0.4876190476190476}, {'note': 'D5', 'duration': 0.7314285714285714}, {'note': 'D♯5', 'duration': 0.4876190476190476}, {'note': 'G4', 'duration': 0.2438095238095238}, {'note': 'D5', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.2438095238095238}, {'note': 'D♯5', 'duration': 0.4876190476190476}, {'note': 'G3', 'duration': 0.4876190476190476}, {'note': 'D♯4', 'duration': 0.4876190476190476}, {'note': 'G♯3', 'duration': 0.4876190476190476}, {'note': 'G3', 'duration': 0.7314285714285714}, {'note': 'G3', 'duration': 0.4876190476190476}, {'note': 'D♯4', 'duration': 0.7314285714285714}, {'note': 'G3', 'duration': 0.2438095238095238}, {'note': 'D♯5', 'duration': 0.2438095238095238}, {'note': 'G4', 'duration': 0.2438095238095238}, {'note': 'D♯4', 'duration': 0.2438095238095238}, {'note': 'G3', 'duration': 0.2438095238095238}, {'note': 'G4', 'duration': 0.7314285714285714}, {'note': 'A♯3', 'duration': 0.2438095238095238}, {'note': 'A♯4', 'duration': 0.2438095238095238}, {'note': 'F5', 'duration': 0.4876190476190476}, {'note': 'E4', 'duration': 0.2438095238095238}, {'note': 'G3', 'duration': 0.2 ...

# %%
from music21 import stream, note, midi

def export_to_musicxml(note_list, output_file="output.musicxml"):
    s = stream.Stream()
    
    for pitch, duration in note_list:
        n = note.Note(pitch)
        n.quarterLength = duration  # Đặt độ dài nốt theo đơn vị quarter
        s.append(n)
    
    s.write('musicxml', fp=output_file)
    print(f"Xuất thành công: {output_file}")

# Ví dụ danh sách nốt (nốt, trường độ)
notes = [("C4", 1.0), ("D4", 0.5), ("E4", 0.5), ("F4", 1.0), ("G4", 2.0)]

# Xuất file MusicXML
export_to_musicxml(notes)

# %%
import torch
import numpy as np
import librosa

def predict_notes(wav_path, model, device="cpu", sr=44100, hop_length=512, window_size=128, step=21):
    print(f"\n🔍 Đang dự đoán file: {wav_path}")

    y, sr = librosa.load(wav_path, sr=sr)
    
    mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, hop_length=hop_length)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

    # Chia thành các cửa sổ (windows)
    X_windows = []
    timestamps = []
    frame_duration = step * hop_length / sr  # Khoảng thời gian của mỗi frame

    for i in range(0, mel_spec_db.shape[1] - window_size, step):
        X_windows.append(mel_spec_db[:, i:i + window_size])
        timestamps.append(i * hop_length / sr)  # Thời gian tính bằng giây
    
    # Chuyển thành tensor
    X_windows = torch.tensor(np.array(X_windows), dtype=torch.float32).unsqueeze(1).to(device)

    model.eval()
    
    batch_size = 32  # Có thể giảm xuống 16 nếu vẫn hết RAM
    num_batches = len(X_windows) // batch_size + 1
    predictions = []
    
    with torch.no_grad():
        for i in range(num_batches):
            batch = X_windows[i * batch_size:(i + 1) * batch_size]
            if batch.shape[0] == 0:
                continue
            outputs = model(batch)
            predictions.append((outputs > 0.5).float().cpu().numpy())
    
    predictions = np.concatenate(predictions, axis=0)

    # Xử lý duration của nốt nhạc
    active_notes = {}  # Lưu trạng thái nốt đang được phát
    note_events = []  # Lưu kết quả cuối cùng

    for i, (time, pred) in enumerate(zip(timestamps, predictions)):
        notes = np.where(pred == 1)[0]  # Lấy danh sách các nốt có giá trị 1

        new_active_notes = set(notes)  # Chuyển sang tập hợp để dễ kiểm tra
        
        # Kiểm tra nốt nào vẫn tiếp tục hoặc mới bắt đầu
        for note in new_active_notes:
            if note not in active_notes:
                active_notes[note] = {"start": time, "duration": frame_duration}
            else:
                active_notes[note]["duration"] += frame_duration

        # Kiểm tra nốt nào đã kết thúc
        ended_notes = set(active_notes.keys()) - new_active_notes
        for note in ended_notes:
            note_events.append({
                "note": note,
                "start": active_notes[note]["start"],
                "end": active_notes[note]["start"] + active_notes[note]["duration"],
                "duration": active_notes[note]["duration"]
            })
            del active_notes[note]

    # Ghi nhận các nốt còn sót lại (kết thúc ở frame cuối)
    for note, info in active_notes.items():
        note_events.append({
            "note": note,
            "start": info["start"],
            "end": info["start"] + info["duration"],
            "duration": info["duration"]
        })

    # Hiển thị kết quả
    print("\n🎼 Kết quả dự đoán:")
    for idx, event in enumerate(sorted(note_events, key=lambda x: x["start"])):
        print(f"{idx+1}. 🎵 Note {event['note']} - Start: {event['start']:.2f}s, End: {event['end']:.2f}s, Duration: {event['duration']:.2f}s")
import gc
import torch

gc.collect()
torch.mps.empty_cache() 
# Dự đoán cho một file WAV
wav_path = "../Data/MusicNet_Dataset/musicnet/musicnet/test_data/1819.wav"
predict_notes(wav_path, model, device=device)
