# %%
import glob

wav_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/train_data/*.wav"))
csv_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/train_labels/*.csv"))

# %%
import time
import torch.optim as optim
import torch.utils.data as data
from Model.CNN_3L_pro import *
import os

# start_file = "../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2443.wav"
# start_index = wav_files.index(start_file) if start_file in wav_files else 0
# 
# wav_files = wav_files[start_index:]
# csv_files = csv_files[start_index:]
# 
# print(f"Bắt đầu train tiếp từ file: {wav_files[0]}")

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# Khởi tạo mô hình, hàm mất mát và optimizer
model = CNN_Pro().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

if os.path.exists("CNN_Pro21.pth"):       
    checkpoint = torch.load("CNN_Pro21.pth", map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# Huấn luyện từng file một
for wav_path, csv_path in zip(wav_files, csv_files):
    print(time.strftime("%H:%M:%S")+f"\nfile : {wav_path}")
    X_train, y_train = load_wav_csv(wav_path, csv_path)
    dataset = MusicDataset(X_train, y_train)
    train_loader = data.DataLoader(dataset, batch_size=64, shuffle=False)

    for epoch in range(20):  # Giảm số epoch cho từng file
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device).float()
            
            optimizer.zero_grad()
            outputs = model(inputs)
             # BCEWithLogitsLoss yêu cầu labels dạng float
            loss = criterion(outputs, labels)  
            loss.backward()
            optimizer.step()
        
            running_loss += loss.item()
            # Chuyển đầu ra thành nhị phân (multi-label classification)
            predicted = (outputs > 0.5).float()
        
            correct += (predicted == labels).sum().item() / 128  # Chia 128 để chuẩn hóa
            total += labels.size(0)

        if epoch >= 19:
            print(f"Epoch {epoch+1}/20, Loss: {running_loss/len(train_loader):.4f}, "
              f"Accuracy: {100 * correct / total:.2f}%")

    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, "CNN_Pro21.pth")
    print(f"Updated checkpoint sau file {wav_path}")

print("done training !")
# Out:
# 16:57:11
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1727.wav
# Epoch 20/20, Loss: 0.1178, Accuracy: 96.43%
# Updated checkpoint sau file ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1727.wav
# 17:04:06
# file : ../Data/MusicNet_Dataset/musicnet/musicnet/train_data/1728.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 52
#      49 loss.backward()
#      50 optimizer.step()
# ---> 52 running_loss += loss.item()
#      53 # Chuyển đầu ra thành nhị phân (multi-label classification)
#      54 predicted = (outputs > 0.5).float()
#
# KeyboardInterrupt:

# %%
import glob
from Model.CNN_3L_pro import *

test_wav_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_data/*.wav"))
test_csv_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_labels/*.csv"))

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

model = CNN_Pro().to(device)
checkpoint = torch.load("../Trained/CNN_Pro.pth", map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()  # Đưa model vào chế độ đánh giá

import numpy as np
import torch.utils.data as data

total_correct = 0
total_samples = 0



for wav_path, csv_path in zip(test_wav_files, test_csv_files):
    print(f"\nĐang test file: {wav_path}")

    X_test, y_test = load_wav_csv(wav_path, csv_path)

    test_dataset = MusicDataset(X_test, y_test)
    test_loader = data.DataLoader(test_dataset, batch_size=64, shuffle=False)

    correct = 0
    total = 0

    with torch.no_grad():  # Không tính gradient khi test
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).float()

            outputs = model(inputs)
            predicted = (outputs > 0.5).float()  # Chuyển thành 0 hoặc 1
            
            correct += (predicted == labels).sum().item() / 128  # Chia 128 để chuẩn hóa
            total += labels.size(0)

    accuracy = 100 * correct / total
    print(f"Accuracy: {accuracy:.2f}%")

    total_correct += correct
    total_samples += total

print(f"\n🔥 Accuracy chung trên tập test: {100 * total_correct / total_samples:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import glob
# ----> 2 from Model.CNN_3L_pro import *
#       4 test_wav_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_data/*.wav"))
#       5 test_csv_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_labels/*.csv"))
#
# File ~/Downloads/Z-Python/Breaking Sounds/Model/CNN_3L_pro.py:7
#       5 import librosa.feature
#       6 import numpy as np
# ----> 7 import pandas as pd
#       8 import torch.utils.data as data
#      11 class CNN_Pro(nn.Module):
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
#      63     PeriodDtype,
#      64     IntervalDtype,
#      65     DatetimeTZDtype,
#      66     StringDtype,
#      67     BooleanDtype,
#      68     # missing
#      69     NA,
#      70     isna,
#      71     isnull,
#      72     notna,
#      73     notnull,
#      74     # indexes
#      75     Index,
#      76     CategoricalIndex,
#      77     RangeIndex,
#      78     MultiIndex,
#      79     IntervalIndex,
#      80     TimedeltaIndex,
#      81     DatetimeIndex,
#      82     PeriodIndex,
#      83     IndexSlice,
#      84     # tseries
#      85     NaT,
#      86     Period,
#      87     period_range,
#      88     Timedelta,
#      89     timedelta_range,
#      90     Timestamp,
#      91     date_range,
#      92     bdate_range,
#      93     Interval,
#      94     interval_range,
#      95     DateOffset,
#      96     # conversion
#      97     to_numeric,
#      98     to_datetime,
#      99     to_timedelta,
#     100     # misc
#     101     Flags,
#     102     Grouper,
#     103     factorize,
#     104     unique,
#     105     value_counts,
#     106     NamedAgg,
#     107     array,
#     108     Categorical,
#     109     set_eng_float_format,
#     110     Series,
#     111     DataFrame,
#     112 )
#     114 from pandas.core.dtypes.dtypes import SparseDtype
#     116 from pandas.tseries.api import infer_freq
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/core/api.py:28
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26     value_counts,
#      27 )
# ---> 28 from pandas.core.arrays import Categorical
#      29 from pandas.core.arrays.boolean import BooleanDtype
#      30 from pandas.core.arrays.floating import (
#      31     Float32Dtype,
#      32     Float64Dtype,
#      33 )
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/core/arrays/__init__.py:1
# ----> 1 from pandas.core.arrays.arrow import ArrowExtensionArray
#       2 from pandas.core.arrays.base import (
#       3     ExtensionArray,
#       4     ExtensionOpsMixin,
#       5     ExtensionScalarOpsMixin,
#       6 )
#       7 from pandas.core.arrays.boolean import BooleanArray
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/core/arrays/arrow/__init__.py:5
#       1 from pandas.core.arrays.arrow.accessors import (
#       2     ListAccessor,
#       3     StructAccessor,
#       4 )
# ----> 5 from pandas.core.arrays.arrow.array import ArrowExtensionArray
#       7 __all__ = ["ArrowExtensionArray", "StructAccessor", "ListAccessor"]
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/core/arrays/arrow/array.py:65
#      60 from pandas.core.arrays.base import (
#      61     ExtensionArray,
#      62     ExtensionArraySupportsAnyAll,
#      63 )
#      64 from pandas.core.arrays.masked import BaseMaskedArray
# ---> 65 from pandas.core.arrays.string_ import StringDtype
#      66 import pandas.core.common as com
#      67 from pandas.core.indexers import (
#      68     check_array_indexer,
#      69     unpack_tuple_and_ellipses,
#      70     validate_indices,
#      71 )
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/core/arrays/string_.py:48
#      40 from pandas.core.arrays.floating import (
#      41     FloatingArray,
#      42     FloatingDtype,
#      43 )
#      44 from pandas.core.arrays.integer import (
#      45     IntegerArray,
#      46     IntegerDtype,
#      47 )
# ---> 48 from pandas.core.arrays.numpy_ import NumpyExtensionArray
#      49 from pandas.core.construction import extract_array
#      50 from pandas.core.indexers import check_array_indexer
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/core/arrays/numpy_.py:29
#      27 from pandas.core.arrays._mixins import NDArrayBackedExtensionArray
#      28 from pandas.core.construction import ensure_wrapped_if_datetimelike
# ---> 29 from pandas.core.strings.object_array import ObjectStringArrayMixin
#      31 if TYPE_CHECKING:
#      32     from pandas._typing import (
#      33         AxisInt,
#      34         Dtype,
#    (...)
#      40         npt,
#      41     )
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/pandas/core/strings/object_array.py:22
#      18 import pandas._libs.ops as libops
#      20 from pandas.core.dtypes.missing import isna
# ---> 22 from pandas.core.strings.base import BaseStringArrayMethods
#      24 if TYPE_CHECKING:
#      25     from collections.abc import Sequence
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1091, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1191, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
from Model.CNN_3L_pro import *
import librosa.display
import gc

gc.collect()
torch.mps.empty_cache()
wav_path = "../Data/MusicNet_Dataset/musicnet/musicnet/test_data/1819.wav"
notes = predict_notes(wav_path, model, device=device)

print(notes)
# Out:
# []

# %%
from music21 import stream, note, midi

def export_to_musicxml(note_list, output_file="output.musicxml"):
    s = stream.Stream()
    
    for pitch, duration in note_list:
        n = note.Note(pitch)
        n.quarterLength = duration  # Đặt độ dài nốt theo đơn vị quarter
        s.append(n)
    
    s.write('musicxml', fp=output_file)
    print(f"Xuất thành công: {output_file}")

# Ví dụ danh sách nốt (nốt, trường độ)
notes = [("C4", 1.0), ("D4", 0.5), ("E4", 0.5), ("F4", 1.0), ("G4", 2.0)]

# Xuất file MusicXML
export_to_musicxml(notes)

# %%
import numpy as np
import librosa
from Model.CNN_3L_pro import *
import gc
import torch

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

model = CNN_Pro().to(device)
checkpoint = torch.load("../Trained/CNN_Pro.pth", map_location=device, weights_only=True)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval() 


gc.collect()
torch.mps.empty_cache() 
# Dự đoán cho một file WAV
wav_path = "../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2106.wav"
notes = CNN_predict(wav_path, model, device=device)
# Out:
# Đang dự đoán file: ../Data/MusicNet_Dataset/musicnet/musicnet/test_data/2106.wav
# [{'note': 50, 'start': 0.4876190476190476, 'duration': 0.4876190476190476}, {'note': 66, 'start': 0.4876190476190476, 'duration': 0.4876190476190476}, {'note': 62, 'start': 0.2438095238095238, 'duration': 0.7314285714285714}, {'note': 69, 'start': 0.9752380952380952, 'duration': 0.2438095238095238}, {'note': 69, 'start': 1.9504761904761905, 'duration': 0.2438095238095238}, {'note': 62, 'start': 2.681904761904762, 'duration': 0.2438095238095238}, {'note': 66, 'start': 3.1695238095238096, 'duration': 0.2438095238095238}, {'note': 73, 'start': 3.900952380952381, 'duration': 0.2438095238095238}, {'note': 66, 'start': 4.144761904761904, 'duration': 0.2438095238095238}, {'note': 62, 'start': 4.388571428571429, 'duration': 0.2438095238095238}, {'note': 74, 'start': 4.388571428571429, 'duration': 0.4876190476190476}, {'note': 86, 'start': 4.388571428571429, 'duration': 0.4876190476190476}, {'note': 62, 'start': 5.12, 'duration': 0.2438095238095238}, {'note': 64, 'start': 5.363809523809524, 'duration': 0.2438095238095238}, {'note': 45, 'start': 5.363809523809524, 'duration': 0.4876190476190476}, {'note': 67, 'start': 6.339047619047619, 'duration': 0.2438095238095238}, {'note': 86, 'start': 7.070476190476191, 'duration': 0.2438095238095238}, {'note': 57, 'start': 9.02095238095238, 'duration': 0.2438095238095238}, {'note': 45, 'start': 9.02095238095238, 'duration': 0.4876190476190476}, {'note': 64, 'start': 9.02095238095238, 'duration': 0.7314285714285714}, {'note': 73, 'start': 9.02095238095238, 'duration': 0.7314285714285714}, {'note': 69, 'start': 9.02095238095238, 'duration': 0.7314285714285714}, {'note': 62, 'start': 9.752380952380953, 'duration': 0.9752380952380952}, {'note': 66, 'start': 10.483809523809525, 'duration': 0.4876190476190476}, {'note': 67, 'start': 11.946666666666667, 'duration': 0.2438095238095238}, {'note': 62, 'start': 12.434285714285714, 'duration': 0.2438095238095238}, {'note': 61, 'start': 12.678095238095239, 'duration': 0.2438095238095238}, {'note': 62, 'start': 12.921904761904761, 'duration': 0.2438095238095238}, {'note': 50, 'start': 13.165714285714285, 'duration': 0.2438095238095238}, {'note': 64, 'start': 13.653333333333334, 'duration': 0.2438095238095238}, {'note': 66, 'start': 13.897142857142857, 'duration': 0.2438095238095238}, {'note': 86, 'start': 13.897142857142857, 'duration': 0.2438095238095238}, {'note': 62, 'start': 13.897142857142857, 'duration': 0.4876190476190476}, {'note': 74, 'start': 14.140952380952381, 'duration': 0.4876190476190476}, {'note': 86, 'start': 14.384761904761906, 'duration': 0.2438095238095238}, {'note': 64, 'start': 14.628571428571428, 'duration': 0.2438095238095238}, {'note': 73, 'start': 14.628571428571428, 'duration': 0.2438095238095238}, {'note': 67, 'start': 14.872380952380952, 'duration': 0.2438095238095238}, {'note': 45, 'start': 15.116190476190477, 'duration': 0.4876190476190476}, {'note': 66, 'start': 16.335238095238097, 'duration': 0.4876190476190476}, {'note': 86, 'start': 16.822857142857142, 'duration': 0.2438095238095238}, {'note': 64, 'start': 18.773333333333333, 'duration': 0.4876190476190476}, {'note': 73, 'start': 18.773333333333333, 'duration': 0.4876190476190476}, {'note': 57, 'start': 18.773333333333333, 'duration': 0.4876190476190476}, {'note': 69, 'start': 18.773333333333333, 'duration': 0.7314285714285714}, {'note': 45, 'start': 18.773333333333333, 'duration': 0.7314285714285714}, {'note': 69, 'start': 19.99238095238095, 'duration': 0.2438095238095238}, {'note': 73, 'start': 19.99238095238095, 'duration': 0.4876190476190476}, {'note': 64, 'start': 20.48, 'duration': 0.2438095238095238}, {'note': 45, 'start': 20.236190476190476, 'duration': 0.4876190476190476}, {'note': 66, 'start': 21.69904761904762, 'duration': 0.2438095238095238}, {'note': 57, 'start': 21.942857142857143, 'duration': 0.2438095238095238}, {'note': 45, 'start': 21.69904761904762, 'duration': 0.7314285714285714}, {'note': 64, 'start': 22.430476190476192, 'duration': 0.2438095238095238}, { ...

# %%
from routes.sounds import *

tempo, _ = get_tempo_pulse(wav_path)
notes_beat = process_notes_sum(notes, tempo)

for idx, event in enumerate(sorted(notes_beat, key=lambda x: x["start_beat"])):
    print(f"{idx+1}. Note {event['note']} - Start: {event['start_beat']:.1f}, Duration: {event['duration_beat']:.3f}, value: {event['note_value']}")
# Out:
# 1. Note 62 - Start: 0.5, Duration: 4.250, value: whole
# 2. Note 50 - Start: 1.0, Duration: 3.000, value: dotted half
# 3. Note 66 - Start: 1.0, Duration: 3.000, value: dotted half
# 4. Note 69 - Start: 2.5, Duration: 1.500, value: dotted quarter
# 5. Note 69 - Start: 5.0, Duration: 1.500, value: dotted quarter
# 6. Note 62 - Start: 6.5, Duration: 1.500, value: dotted quarter
# 7. Note 66 - Start: 8.0, Duration: 1.500, value: dotted quarter
# 8. Note 73 - Start: 9.5, Duration: 1.500, value: dotted quarter
# 9. Note 66 - Start: 10.0, Duration: 1.500, value: dotted quarter
# 10. Note 62 - Start: 11.0, Duration: 1.500, value: dotted quarter
# 11. Note 74 - Start: 11.0, Duration: 3.000, value: dotted half
# 12. Note 86 - Start: 11.0, Duration: 3.000, value: dotted half
# 13. Note 62 - Start: 12.5, Duration: 1.500, value: dotted quarter
# 14. Note 64 - Start: 13.0, Duration: 1.500, value: dotted quarter
# 15. Note 45 - Start: 13.0, Duration: 3.000, value: dotted half
# 16. Note 67 - Start: 15.5, Duration: 1.500, value: dotted quarter
# 17. Note 86 - Start: 17.5, Duration: 1.500, value: dotted quarter
# 18. Note 57 - Start: 22.0, Duration: 1.500, value: dotted quarter
# 19. Note 45 - Start: 22.0, Duration: 3.000, value: dotted half
# 20. Note 64 - Start: 22.0, Duration: 4.250, value: whole
# 21. Note 73 - Start: 22.0, Duration: 4.250, value: whole
# 22. Note 69 - Start: 22.0, Duration: 4.250, value: whole
# 23. Note 62 - Start: 24.0, Duration: 5.875, value: whole
# 24. Note 66 - Start: 25.5, Duration: 3.000, value: dotted half
# 25. Note 67 - Start: 29.5, Duration: 1.500, value: dotted quarter
# 26. Note 62 - Start: 30.5, Duration: 1.500, value: dotted quarter
# 27. Note 61 - Start: 31.0, Duration: 1.500, value: dotted quarter
# 28. Note 62 - Start: 31.5, Duration: 1.500, value: dotted quarter
# 29. Note 50 - Start: 32.5, Duration: 1.500, value: dotted quarter
# 30. Note 64 - Start: 33.5, Duration: 1.500, value: dotted quarter
# 31. Note 66 - Start: 34.0, Duration: 1.500, value: dotted quarter
# 32. Note 86 - Start: 34.0, Duration: 1.500, value: dotted quarter
# 33. Note 62 - Start: 34.0, Duration: 3.000, value: dotted half
# 34. Note 74 - Start: 34.5, Duration: 3.000, value: dotted half
# 35. Note 86 - Start: 35.0, Duration: 1.500, value: dotted quarter
# 36. Note 64 - Start: 36.0, Duration: 1.500, value: dotted quarter
# 37. Note 73 - Start: 36.0, Duration: 1.500, value: dotted quarter
# 38. Note 67 - Start: 36.5, Duration: 1.500, value: dotted quarter
# 39. Note 45 - Start: 37.0, Duration: 3.000, value: dotted half
# 40. Note 66 - Start: 40.0, Duration: 3.000, value: dotted half
# 41. Note 86 - Start: 41.0, Duration: 1.500, value: dotted quarter
# 42. Note 64 - Start: 46.0, Duration: 3.000, value: dotted half
# 43. Note 73 - Start: 46.0, Duration: 3.000, value: dotted half
# 44. Note 57 - Start: 46.0, Duration: 3.000, value: dotted half
# 45. Note 69 - Start: 46.0, Duration: 4.250, value: whole
# 46. Note 45 - Start: 46.0, Duration: 4.250, value: whole
# 47. Note 69 - Start: 49.0, Duration: 1.500, value: dotted quarter
# 48. Note 73 - Start: 49.0, Duration: 3.000, value: dotted half
# 49. Note 45 - Start: 49.5, Duration: 3.000, value: dotted half
# 50. Note 64 - Start: 50.0, Duration: 1.500, value: dotted quarter
# 51. Note 66 - Start: 53.0, Duration: 1.500, value: dotted quarter
# 52. Note 45 - Start: 53.0, Duration: 4.250, value: whole
# 53. Note 57 - Start: 54.0, Duration: 1.500, value: dotted quarter
# 54. Note 64 - Start: 55.0, Duration: 1.500, value: dotted quarter
# 55. Note 73 - Start: 55.0, Duration: 1.500, value: dotted quarter
# 56. Note 45 - Start: 55.5, Duration: 4.250, value: whole
# 57. Note 62 - Start: 57.5, Duration: 3.000, value: dotted half
# 58. Note 65 - Start: 58.0, Duration: 4.250, value: whole
# 59. Note 74 - Start: 58.0, Duration: 4.250, value: whole
# 60. Note 86 - Start: 58.0, Duration: 4.250, value: whole
# 61. Note 53 - Start: 59.0, Duration: 1.500, value: dotted quarter
# 62. Note 58 - Start: 61.5, Duration: 1.500, value: dotted quarter
# 63. Note 73 - Start: 64.0, Duration: 1.500, value: dotted quarter
# 64. Note 74 - Start: 65.0, Duration: 1.500, value: dotted quarter
# 65. Note 53 - Start: 65.0, Duration: 1.500, value: dotted quarter
# 66. Note 86 - Start: 65.0, Duration: 1.500, value: dotted quarter
# 67. Note 64 - Start: 66.5, Duration: 1.500, value: dotted quarter
# 68. Note 73 - Start: 66.5, Duration: 1.500, value: dotted quarter
# 69. Note 45 - Start: 66.5, Duration: 3.000, value: dotted half
# 70. Note 69 - Start: 67.0, Duration: 1.500, value: dotted quarter
# 71. Note 65 - Start: 68.0, Duration: 3.000, value: dotted half
# 72. Note 62 - Start: 68.5, Duration: 1.500, value: dotted quarter
# 73. Note 61 - Start: 71.0, Duration: 1.500, value: dotted quarter
# 74. Note 62 - Start: 71.5, Duration: 3.000, value: dotted half
# 75. Note 66 - Start: 73.5, Duration: 1.500, value: dotted quarter
# 76. Note 67 - Start: 77.0, Duration: 1.500, value: dotted quarter
# 77. Note 62 - Start: 78.5, Duration: 1.500, value: dotted quarter
# 78. Note 61 - Start: 79.0, Duration: 1.500, value: dotted quarter
# 79. Note 65 - Start: 79.5, Duration: 1.500, value: dotted quarter
# 80. Note 66 - Start: 79.5, Duration: 1.500, value: dotted quarter
# 81. Note 50 - Start: 82.0, Duration: 3.000, value: dotted half
# 82. Note 62 - Start: 82.0, Duration: 3.000, value: dotted half
# 83. Note 74 - Start: 82.5, Duration: 3.000, value: dotted half
# 84. Note 86 - Start: 83.0, Duration: 1.500, value: dotted quarter
# 85. Note 64 - Start: 85.0, Duration: 1.500, value: dotted quarter
# 86. Note 79 - Start: 85.0, Duration: 1.500, value: dotted quarter
# 87. Note 67 - Start: 85.0, Duration: 5.875, value: whole
# 88. Note 57 - Start: 95.5, Duration: 1.500, value: dotted quarter
# 89. Note 67 - Start: 98.0, Duration: 1.500, value: dotted quarter
# 90. Note 64 - Start: 98.5, Duration: 1.500, value: dotted quarter
# 91. Note 73 - Start: 98.5, Duration: 3.000, value: dotted half
# 92. Note 57 - Start: 98.5, Duration: 3.000, value: dotted half
# 93. Note 50 - Start: 100.0, Duration: 3.000, value: dotted half
# 94. Note 74 - Start: 100.0, Duration: 3.000, value: dotted half
# 95. Note 62 - Start: 100.0, Duration: 4.250, value: whole
# 96. Note 74 - Start: 101.5, Duration: 3.000, value: dotted half
# 97. Note 66 - Start: 104.0, Duration: 3.000, value: dotted half
# 98. Note 67 - Start: 104.5, Duration: 3.000, value: dotted half
# 99. Note 69 - Start: 106.5, Duration: 3.000, value: dotted half
# 100. Note 66 - Start: 107.5, Duration: 1.500, value: dotted quarter
# 101. Note 78 - Start: 107.5, Duration: 1.500, value: dotted quarter
# 102. Note 64 - Start: 108.5, Duration: 1.500, value: dotted quarter
# 103. Note 62 - Start: 110.5, Duration: 4.250, value: whole
# 104. Note 59 - Start: 111.5, Duration: 3.000, value: dotted half
# 105. Note 55 - Start: 111.5, Duration: 3.000, value: dotted half
# 106. Note 67 - Start: 112.5, Duration: 1.500, value: dotted quarter
# 107. Note 56 - Start: 114.5, Duration: 1.500, value: dotted quarter
# 108. Note 65 - Start: 114.5, Duration: 1.500, value: dotted quarter
# 109. Note 61 - Start: 115.5, Duration: 1.500, value: dotted quarter
# 110. Note 62 - Start: 115.5, Duration: 4.250, value: whole
# 111. Note 61 - Start: 118.5, Duration: 1.500, value: dotted quarter
# 112. Note 62 - Start: 119.0, Duration: 3.000, value: dotted half
# 113. Note 65 - Start: 119.5, Duration: 1.500, value: dotted quarter
# 114. Note 74 - Start: 120.5, Duration: 3.000, value: dotted half
# 115. Note 58 - Start: 121.5, Duration: 1.500, value: dotted quarter
# 116. Note 62 - Start: 121.5, Duration: 5.875, value: whole
# 117. Note 58 - Start: 122.5, Duration: 3.000, value: dotted half
# 118. Note 74 - Start: 123.0, Duration: 1.500, value: dotted quarter
# 119. Note 59 - Start: 124.0, Duration: 1.500, value: dotted quarter
# 120. Note 62 - Start: 124.0, Duration: 4.250, value: whole
# 121. Note 78 - Start: 125.5, Duration: 1.500, value: dotted quarter
# 122. Note 74 - Start: 126.5, Duration: 1.500, value: dotted quarter
# 123. Note 62 - Start: 128.0, Duration: 3.000, value: dotted half
# 124. Note 78 - Start: 129.0, Duration: 1.500, value: dotted quarter
# 125. Note 59 - Start: 134.0, Duration: 3.000, value: dotted half
# 126. Note 83 - Start: 134.5, Duration: 1.500, value: dotted quarter
# 127. Note 67 - Start: 135.0, Duration: 1.500, value: dotted quarter
# 128. Note 57 - Start: 136.0, Duration: 3.000, value: dotted half
# 129. Note 66 - Start: 137.0, Duration: 1.500, value: dotted quarter
# 130. Note 86 - Start: 138.0, Duration: 1.500, value: dotted quarter
# 131. Note 74 - Start: 138.0, Duration: 1.500, value: dotted quarter
# 132. Note 62 - Start: 138.0, Duration: 1.500, value: dotted quarter
# 133. Note 66 - Start: 141.5, Duration: 1.500, value: dotted quarter
# 134. Note 38 - Start: 144.0, Duration: 1.500, value: dotted quarter
# 135. Note 66 - Start: 146.5, Duration: 1.500, value: dotted quarter
# 136. Note 81 - Start: 147.0, Duration: 1.500, value: dotted quarter
# 137. Note 69 - Start: 147.0, Duration: 1.500, value: dotted quarter
# 138. Note 66 - Start: 147.5, Duration: 1.500, value: dotted quarter
# 139. Note 78 - Start: 147.5, Duration: 1.500, value: dotted quarter
# 140. Note 66 - Start: 148.5, Duration: 1.500, value: dotted quarter
# 141. Note 69 - Start: 151.0, Duration: 1.500, value: dotted quarter
# 142. Note 73 - Start: 151.0, Duration: 4.250, value: whole
# 143. Note 45 - Start: 151.0, Duration: 7.375, value: whole
# 144. Note 64 - Start: 151.5, Duration: 4.250, value: whole
# 145. Note 69 - Start: 153.5, Duration: 1.500, value: dotted quarter
# 146. Note 45 - Start: 156.0, Duration: 7.375, value: whole
# 147. Note 57 - Start: 156.5, Duration: 1.500, value: dotted quarter
# 148. Note 64 - Start: 156.5, Duration: 4.250, value: whole
# 149. Note 57 - Start: 158.5, Duration: 1.500, value: dotted quarter
# 150. Note 64 - Start: 159.0, Duration: 1.500, value: dotted quarter
# 151. Note 73 - Start: 159.5, Duration: 1.500, value: dotted quarter
# 152. Note 62 - Start: 160.0, Duration: 1.500, value: dotted quarter
# 153. Note 58 - Start: 160.5, Duration: 1.500, value: dotted quarter
# 154. Note 74 - Start: 160.5, Duration: 5.875, value: whole
# 155. Note 62 - Start: 161.5, Duration: 3.000, value: dotted half
# 156. Note 86 - Start: 161.5, Duration: 4.250, value: whole
# 157. Note 53 - Start: 162.0, Duration: 1.500, value: dotted quarter
# 158. Note 65 - Start: 162.0, Duration: 3.000, value: dotted half
# 159. Note 64 - Start: 164.5, Duration: 1.500, value: dotted quarter
# 160. Note 58 - Start: 164.5, Duration: 1.500, value: dotted quarter
# 161. Note 88 - Start: 164.5, Duration: 1.500, value: dotted quarter
# 162. Note 73 - Start: 166.5, Duration: 1.500, value: dotted quarter
# 163. Note 62 - Start: 168.5, Duration: 1.500, value: dotted quarter
# 164. Note 50 - Start: 168.5, Duration: 1.500, value: dotted quarter
# 165. Note 74 - Start: 168.5, Duration: 1.500, value: dotted quarter
# 166. Note 86 - Start: 168.5, Duration: 1.500, value: dotted quarter
# 167. Note 45 - Start: 169.5, Duration: 3.000, value: dotted half
# 168. Note 69 - Start: 169.5, Duration: 4.250, value: whole
# 169. Note 73 - Start: 170.0, Duration: 1.500, value: dotted quarter
# 170. Note 64 - Start: 170.0, Duration: 3.000, value: dotted half
# 171. Note 65 - Start: 171.5, Duration: 1.500, value: dotted quarter
# 172. Note 62 - Start: 171.5, Duration: 3.000, value: dotted half
# 173. Note 73 - Start: 173.0, Duration: 4.250, value: whole
# 174. Note 64 - Start: 174.5, Duration: 1.500, value: dotted quarter
# 175. Note 62 - Start: 175.5, Duration: 3.000, value: dotted half
# 176. Note 66 - Start: 176.0, Duration: 3.000, value: dotted half
# 177. Note 62 - Start: 181.5, Duration: 1.500, value: dotted quarter
# 178. Note 66 - Start: 183.0, Duration: 1.500, value: dotted quarter
# 179. Note 62 - Start: 183.0, Duration: 1.500, value: dotted quarter
# 180. Note 50 - Start: 185.0, Duration: 1.500, value: dotted quarter
# 181. Note 74 - Start: 185.0, Duration: 1.500, value: dotted quarter
# 182. Note 86 - Start: 185.0, Duration: 1.500, value: dotted quarter
# 183. Note 62 - Start: 185.0, Duration: 4.250, value: whole
# 184. Note 74 - Start: 186.5, Duration: 1.500, value: dotted quarter
# 185. Note 86 - Start: 186.5, Duration: 1.500, value: dotted quarter
# 186. Note 67 - Start: 188.0, Duration: 1.500, value: dotted quarter
# 187. Note 64 - Start: 189.5, Duration: 1.500, value: dotted quarter
# 188. Note 67 - Start: 189.5, Duration: 1.500, value: dotted quarter
# 189. Note 79 - Start: 189.5, Duration: 1.500, value: dotted quarter
# 190. Note 74 - Start: 194.0, Duration: 1.500, value: dotted quarter
# 191. Note 83 - Start: 194.0, Duration: 1.500, value: dotted quarter
# 192. Note 57 - Start: 199.0, Duration: 1.500, value: dotted quarter
# 193. Note 62 - Start: 200.0, Duration: 1.500, value: dotted quarter
# 194. Note 50 - Start: 200.0, Duration: 1.500, value: dotted quarter
# 195. Note 66 - Start: 200.0, Duration: 1.500, value: dotted quarter
# 196. Note 78 - Start: 200.0, Duration: 1.500, value: dotted quarter
# 197. Note 62 - Start: 203.0, Duration: 4.250, value: whole
# 198. Note 74 - Start: 203.5, Duration: 3.000, value: dotted half
# 199. Note 50 - Start: 204.5, Duration: 1.500, value: dotted quarter
# 200. Note 74 - Start: 205.5, Duration: 3.000, value: dotted half
# 201. Note 66 - Start: 208.0, Duration: 1.500, value: dotted quarter
# 202. Note 67 - Start: 208.0, Duration: 4.250, value: whole
# 203. Note 64 - Start: 209.0, Duration: 1.500, value: dotted quarter
# 204. Note 66 - Start: 211.5, Duration: 1.500, value: dotted quarter
# 205. Note 67 - Start: 212.5, Duration: 1.500, value: dotted quarter
# 206. Note 68 - Start: 214.0, Duration: 1.500, value: dotted quarter
# 207. Note 69 - Start: 214.5, Duration: 1.500, value: dotted quarter
# 208. Note 62 - Start: 214.5, Duration: 4.250, value: whole
# 209. Note 59 - Start: 215.5, Duration: 7.375, value: whole
# 210. Note 67 - Start: 216.0, Duration: 1.500, value: dotted quarter
# 211. Note 55 - Start: 216.0, Duration: 1.500, value: dotted quarter
# 212. Note 83 - Start: 218.5, Duration: 1.500, value: dotted quarter
# 213. Note 56 - Start: 219.0, Duration: 1.500, value: dotted quarter
# 214. Note 62 - Start: 220.5, Duration: 1.500, value: dotted quarter
# 215. Note 62 - Start: 223.0, Duration: 3.000, value: dotted half
# 216. Note 58 - Start: 224.5, Duration: 3.000, value: dotted half
# 217. Note 74 - Start: 224.5, Duration: 3.000, value: dotted half
# 218. Note 62 - Start: 226.0, Duration: 4.250, value: whole
# 219. Note 58 - Start: 226.5, Duration: 3.000, value: dotted half
# 220. Note 74 - Start: 227.0, Duration: 1.500, value: dotted quarter
# 221. Note 62 - Start: 229.0, Duration: 3.000, value: dotted half
# 222. Note 74 - Start: 230.5, Duration: 1.500, value: dotted quarter
# 223. Note 62 - Start: 232.0, Duration: 1.500, value: dotted quarter
# 224. Note 59 - Start: 237.5, Duration: 1.500, value: dotted quarter
# 225. Note 79 - Start: 237.5, Duration: 1.500, value: dotted quarter
# 226. Note 67 - Start: 238.5, Duration: 1.500, value: dotted quarter
# 227. Note 55 - Start: 238.5, Duration: 4.250, value: whole
# 228. Note 59 - Start: 239.0, Duration: 1.500, value: dotted quarter
# 229. Note 83 - Start: 239.0, Duration: 1.500, value: dotted quarter
# 230. Note 64 - Start: 239.5, Duration: 1.500, value: dotted quarter
# 231. Note 67 - Start: 239.5, Duration: 1.500, value: dotted quarter
# 232. Note 74 - Start: 240.5, Duration: 1.500, value: dotted quarter
# 233. Note 66 - Start: 240.5, Duration: 3.000, value: dotted half
# 234. Note 57 - Start: 240.5, Duration: 5.875, value: whole
# 235. Note 66 - Start: 242.5, Duration: 1.500, value: dotted quarter
# 236. Note 62 - Start: 242.5, Duration: 1.500, value: dotted quarter
# 237. Note 66 - Start: 246.0, Duration: 1.500, value: dotted quarter
# 238. Note 66 - Start: 251.0, Duration: 1.500, value: dotted quarter
# 239. Note 69 - Start: 251.5, Duration: 1.500, value: dotted quarter
# 240. Note 66 - Start: 252.5, Duration: 3.000, value: dotted half
# 241. Note 61 - Start: 255.0, Duration: 1.500, value: dotted quarter
# 242. Note 65 - Start: 258.0, Duration: 1.500, value: dotted quarter
# 243. Note 68 - Start: 258.0, Duration: 1.500, value: dotted quarter
# 244. Note 62 - Start: 258.0, Duration: 1.500, value: dotted quarter
# 245. Note 61 - Start: 259.0, Duration: 3.000, value: dotted half
# 246. Note 69 - Start: 260.0, Duration: 1.500, value: dotted quarter
# 247. Note 59 - Start: 261.5, Duration: 1.500, value: dotted quarter
# 248. Note 67 - Start: 261.5, Duration: 4.250, value: whole
# 249. Note 66 - Start: 262.0, Duration: 3.000, value: dotted half
# 250. Note 59 - Start: 263.0, Duration: 1.500, value: dotted quarter
# 251. Note 62 - Start: 263.5, Duration: 1.500, value: dotted quarter
# 252. Note 64 - Start: 264.0, Duration: 1.500, value: dotted quarter
# 253. Note 58 - Start: 264.0, Duration: 1.500, value: dotted quarter
# 254. Note 57 - Start: 264.5, Duration: 4.250, value: whole
# 255. Note 64 - Start: 267.0, Duration: 1.500, value: dotted quarter
# 256. Note 60 - Start: 267.0, Duration: 1.500, value: dotted quarter
# 257. Note 65 - Start: 267.5, Duration: 3.000, value: dotted half
# 258. Note 57 - Start: 267.5, Duration: 3.000, value: dotted half
# 259. Note 69 - Start: 268.0, Duration: 1.500, value: dotted quarter
# 260. Note 65 - Start: 269.5, Duration: 1.500, value: dotted quarter
# 261. Note 72 - Start: 270.5, Duration: 3.000, value: dotted half
# 262. Note 72 - Start: 273.5, Duration: 1.500, value: dotted quarter
# 263. Note 77 - Start: 274.0, Duration: 1.500, value: dotted quarter
# 264. Note 69 - Start: 274.0, Duration: 1.500, value: dotted quarter
# 265. Note 84 - Start: 275.0, Duration: 3.000, value: dotted half
# 266. Note 72 - Start: 275.5, Duration: 1.500, value: dotted quarter
# 267. Note 82 - Start: 275.5, Duration: 1.500, value: dotted quarter
# 268. Note 60 - Start: 275.5, Duration: 1.500, value: dotted quarter
# 269. Note 81 - Start: 276.0, Duration: 1.500, value: dotted quarter
# 270. Note 65 - Start: 276.0, Duration: 1.500, value: dotted quarter
# 271. Note 53 - Start: 276.0, Duration: 1.500, value: dotted quarter
# 272. Note 70 - Start: 278.0, Duration: 3.000, value: dotted half
# 273. Note 82 - Start: 278.0, Duration: 3.000, value: dotted half
# 274. Note 72 - Start: 278.5, Duration: 1.500, value: dotted quarter
# 275. Note 84 - Start: 278.5, Duration: 1.500, value: dotted quarter
# 276. Note 60 - Start: 278.5, Duration: 1.500, value: dotted quarter
# 277. Note 81 - Start: 279.0, Duration: 1.500, value: dotted quarter
# 278. Note 65 - Start: 279.0, Duration: 1.500, value: dotted quarter
# 279. Note 53 - Start: 279.0, Duration: 1.500, value: dotted quarter
# 280. Note 70 - Start: 279.5, Duration: 1.500, value: dotted quarter
# 281. Note 65 - Start: 280.0, Duration: 1.500, value: dotted quarter
# 282. Note 70 - Start: 280.5, Duration: 1.500, value: dotted quarter
# 283. Note 82 - Start: 280.5, Duration: 3.000, value: dotted half
# 284. Note 69 - Start: 282.0, Duration: 1.500, value: dotted quarter
# 285. Note 65 - Start: 282.5, Duration: 1.500, value: dotted quarter
# 286. Note 69 - Start: 283.0, Duration: 1.500, value: dotted quarter
# 287. Note 65 - Start: 285.0, Duration: 1.500, value: dotted quarter
# 288. Note 70 - Start: 287.5, Duration: 1.500, value: dotted quarter
# 289. Note 58 - Start: 287.5, Duration: 1.500, value: dotted quarter
# 290. Note 62 - Start: 287.5, Duration: 1.500, value: dotted quarter
# 291. Note 50 - Start: 287.5, Duration: 3.000, value: dotted half
# 292. Note 70 - Start: 288.5, Duration: 1.500, value: dotted quarter
# 293. Note 70 - Start: 289.5, Duration: 1.500, value: dotted quarter
# 294. Note 69 - Start: 290.5, Duration: 1.500, value: dotted quarter
# 295. Note 48 - Start: 290.5, Duration: 5.875, value: whole
# 296. Note 70 - Start: 291.0, Duration: 1.500, value: dotted quarter
# 297. Note 65 - Start: 293.5, Duration: 3.000, value: dotted half
# 298. Note 41 - Start: 293.5, Duration: 3.000, value: dotted half
# 299. Note 69 - Start: 297.5, Duration: 1.500, value: dotted quarter
# 300. Note 62 - Start: 298.0, Duration: 1.500, value: dotted quarter
# 301. Note 68 - Start: 298.5, Duration: 3.000, value: dotted half
# 302. Note 61 - Start: 299.5, Duration: 4.250, value: whole
# 303. Note 64 - Start: 300.5, Duration: 1.500, value: dotted quarter
# 304. Note 66 - Start: 301.5, Duration: 3.000, value: dotted half
# 305. Note 67 - Start: 301.5, Duration: 5.875, value: whole
# 306. Note 59 - Start: 302.5, Duration: 4.250, value: whole
# 307. Note 86 - Start: 303.0, Duration: 1.500, value: dotted quarter
# 308. Note 62 - Start: 303.5, Duration: 1.500, value: dotted quarter
# 309. Note 58 - Start: 304.0, Duration: 1.500, value: dotted quarter
# 310. Note 57 - Start: 304.5, Duration: 4.250, value: whole
# 311. Note 65 - Start: 306.0, Duration: 1.500, value: dotted quarter
# 312. Note 64 - Start: 307.0, Duration: 1.500, value: dotted quarter
# 313. Note 57 - Start: 307.5, Duration: 1.500, value: dotted quarter
# 314. Note 65 - Start: 307.5, Duration: 5.875, value: whole
# 315. Note 69 - Start: 308.0, Duration: 1.500, value: dotted quarter
# 316. Note 71 - Start: 310.0, Duration: 1.500, value: dotted quarter
# 317. Note 64 - Start: 310.5, Duration: 3.000, value: dotted half
# 318. Note 72 - Start: 310.5, Duration: 3.000, value: dotted half
# 319. Note 72 - Start: 313.0, Duration: 1.500, value: dotted quarter
# 320. Note 72 - Start: 315.0, Duration: 3.000, value: dotted half
# 321. Note 82 - Start: 315.5, Duration: 1.500, value: dotted quarter
# 322. Note 84 - Start: 315.5, Duration: 1.500, value: dotted quarter
# 323. Note 53 - Start: 316.0, Duration: 1.500, value: dotted quarter
# 324. Note 84 - Start: 317.0, Duration: 1.500, value: dotted quarter
# 325. Note 53 - Start: 317.0, Duration: 1.500, value: dotted quarter
# 326. Note 72 - Start: 318.0, Duration: 3.000, value: dotted half
# 327. Note 70 - Start: 318.5, Duration: 1.500, value: dotted quarter
# 328. Note 82 - Start: 318.5, Duration: 3.000, value: dotted half
# 329. Note 65 - Start: 319.0, Duration: 1.500, value: dotted quarter
# 330. Note 81 - Start: 319.0, Duration: 1.500, value: dotted quarter
# 331. Note 53 - Start: 319.0, Duration: 1.500, value: dotted quarter
# 332. Note 53 - Start: 320.0, Duration: 1.500, value: dotted quarter
# 333. Note 70 - Start: 321.0, Duration: 1.500, value: dotted quarter
# 334. Note 82 - Start: 321.0, Duration: 3.000, value: dotted half
# 335. Note 72 - Start: 321.5, Duration: 1.500, value: dotted quarter
# 336. Note 60 - Start: 321.5, Duration: 1.500, value: dotted quarter
# 337. Note 53 - Start: 322.0, Duration: 1.500, value: dotted quarter
# 338. Note 65 - Start: 322.0, Duration: 3.000, value: dotted half
# 339. Note 69 - Start: 323.0, Duration: 1.500, value: dotted quarter
# 340. Note 53 - Start: 324.5, Duration: 1.500, value: dotted quarter
# 341. Note 65 - Start: 325.0, Duration: 3.000, value: dotted half
# 342. Note 69 - Start: 327.5, Duration: 1.500, value: dotted quarter
# 343. Note 81 - Start: 327.5, Duration: 3.000, value: dotted half
# 344. Note 70 - Start: 327.5, Duration: 4.250, value: whole
# 345. Note 50 - Start: 328.0, Duration: 1.500, value: dotted quarter
# 346. Note 81 - Start: 330.5, Duration: 1.500, value: dotted quarter
# 347. Note 65 - Start: 330.5, Duration: 1.500, value: dotted quarter
# 348. Note 48 - Start: 330.5, Duration: 3.000, value: dotted half
# 349. Note 69 - Start: 330.5, Duration: 3.000, value: dotted half
# 350. Note 48 - Start: 332.0, Duration: 1.500, value: dotted quarter
# 351. Note 57 - Start: 333.5, Duration: 3.000, value: dotted half
# 352. Note 41 - Start: 333.5, Duration: 3.000, value: dotted half
# 353. Note 65 - Start: 333.5, Duration: 4.250, value: whole
# 354. Note 53 - Start: 333.5, Duration: 4.250, value: whole
# 355. Note 62 - Start: 335.5, Duration: 1.500, value: dotted quarter
# 356. Note 64 - Start: 336.5, Duration: 1.500, value: dotted quarter
# 357. Note 79 - Start: 336.5, Duration: 1.500, value: dotted quarter
# 358. Note 64 - Start: 340.0, Duration: 1.500, value: dotted quarter
# 359. Note 57 - Start: 340.5, Duration: 1.500, value: dotted quarter
# 360. Note 67 - Start: 342.5, Duration: 3.000, value: dotted half
# 361. Note 61 - Start: 346.5, Duration: 1.500, value: dotted quarter
# 362. Note 58 - Start: 349.5, Duration: 1.500, value: dotted quarter
# 363. Note 56 - Start: 350.0, Duration: 1.500, value: dotted quarter
# 364. Note 65 - Start: 350.0, Duration: 1.500, value: dotted quarter
# 365. Note 74 - Start: 350.0, Duration: 1.500, value: dotted quarter
# 366. Note 62 - Start: 354.0, Duration: 1.500, value: dotted quarter
# 367. Note 70 - Start: 355.5, Duration: 1.500, value: dotted quarter
# 368. Note 53 - Start: 356.5, Duration: 1.500, value: dotted quarter
# 369. Note 65 - Start: 358.5, Duration: 1.500, value: dotted quarter
# 370. Note 62 - Start: 358.5, Duration: 1.500, value: dotted quarter
# 371. Note 62 - Start: 359.5, Duration: 1.500, value: dotted quarter
# 372. Note 74 - Start: 360.0, Duration: 1.500, value: dotted quarter
# 373. Note 57 - Start: 362.5, Duration: 1.500, value: dotted quarter
# 374. Note 62 - Start: 362.5, Duration: 3.000, value: dotted half
# 375. Note 66 - Start: 362.5, Duration: 3.000, value: dotted half
# 376. Note 50 - Start: 362.5, Duration: 3.000, value: dotted half
# 377. Note 38 - Start: 362.5, Duration: 3.000, value: dotted half
# 378. Note 81 - Start: 365.0, Duration: 1.500, value: dotted quarter
# 379. Note 62 - Start: 365.0, Duration: 1.500, value: dotted quarter
# 380. Note 64 - Start: 365.5, Duration: 1.500, value: dotted quarter
# 381. Note 57 - Start: 365.5, Duration: 1.500, value: dotted quarter
# 382. Note 79 - Start: 365.5, Duration: 1.500, value: dotted quarter
# 383. Note 67 - Start: 367.0, Duration: 1.500, value: dotted quarter
# 384. Note 74 - Start: 368.0, Duration: 1.500, value: dotted quarter
# 385. Note 77 - Start: 368.0, Duration: 1.500, value: dotted quarter
# 386. Note 67 - Start: 368.0, Duration: 3.000, value: dotted half
# 387. Note 57 - Start: 369.5, Duration: 1.500, value: dotted quarter
# 388. Note 64 - Start: 371.5, Duration: 1.500, value: dotted quarter
# 389. Note 67 - Start: 373.5, Duration: 3.000, value: dotted half
# 390. Note 61 - Start: 375.0, Duration: 1.500, value: dotted quarter
# 391. Note 62 - Start: 375.0, Duration: 3.000, value: dotted half
# 392. Note 74 - Start: 378.5, Duration: 1.500, value: dotted quarter
# 393. Note 62 - Start: 383.5, Duration: 1.500, value: dotted quarter
# 394. Note 45 - Start: 386.5, Duration: 1.500, value: dotted quarter
# 395. Note 57 - Start: 387.0, Duration: 1.500, value: dotted quarter
# 396. Note 65 - Start: 388.5, Duration: 1.500, value: dotted quarter
# 397. Note 61 - Start: 392.0, Duration: 3.000, value: dotted half
# 398. Note 45 - Start: 392.0, Duration: 3.000, value: dotted half
# 399. Note 64 - Start: 392.5, Duration: 1.500, value: dotted quarter
# 400. Note 73 - Start: 392.5, Duration: 1.500, value: dotted quarter
# 401. Note 57 - Start: 392.5, Duration: 5.875, value: whole
# 402. Note 50 - Start: 393.0, Duration: 4.250, value: whole
# 403. Note 62 - Start: 393.0, Duration: 5.875, value: whole
# 404. Note 66 - Start: 393.0, Duration: 7.375, value: whole
# 405. Note 38 - Start: 393.5, Duration: 4.250, value: whole
# 406. Note 62 - Start: 398.0, Duration: 3.000, value: dotted half
# 407. Note 66 - Start: 398.0, Duration: 4.250, value: whole
# 408. Note 50 - Start: 398.5, Duration: 4.250, value: whole
# 409. Note 62 - Start: 399.5, Duration: 1.500, value: dotted quarter
# 410. Note 67 - Start: 402.0, Duration: 1.500, value: dotted quarter
# 411. Note 61 - Start: 403.0, Duration: 1.500, value: dotted quarter
# 412. Note 62 - Start: 404.0, Duration: 1.500, value: dotted quarter
# 413. Note 50 - Start: 406.0, Duration: 1.500, value: dotted quarter
# 414. Note 74 - Start: 407.5, Duration: 3.000, value: dotted half
# 415. Note 62 - Start: 407.5, Duration: 3.000, value: dotted half
# 416. Note 86 - Start: 407.5, Duration: 4.250, value: whole
# 417. Note 67 - Start: 409.0, Duration: 1.500, value: dotted quarter
# 418. Note 61 - Start: 410.0, Duration: 1.500, value: dotted quarter
# 419. Note 45 - Start: 410.0, Duration: 4.250, value: whole
# 420. Note 66 - Start: 413.5, Duration: 1.500, value: dotted quarter
# 421. Note 62 - Start: 413.5, Duration: 1.500, value: dotted quarter
# 422. Note 73 - Start: 419.5, Duration: 1.500, value: dotted quarter
# 423. Note 64 - Start: 419.5, Duration: 4.250, value: whole
# 424. Note 45 - Start: 419.5, Duration: 4.250, value: whole
# 425. Note 69 - Start: 420.0, Duration: 1.500, value: dotted quarter
# 426. Note 62 - Start: 421.5, Duration: 4.250, value: whole
# 427. Note 50 - Start: 423.0, Duration: 1.500, value: dotted quarter
# 428. Note 57 - Start: 423.0, Duration: 3.000, value: dotted half
# 429. Note 66 - Start: 423.5, Duration: 1.500, value: dotted quarter
# 430. Note 62 - Start: 429.0, Duration: 3.000, value: dotted half
# 431. Note 50 - Start: 429.5, Duration: 1.500, value: dotted quarter
# 432. Note 66 - Start: 432.0, Duration: 1.500, value: dotted quarter
# 433. Note 74 - Start: 432.5, Duration: 1.500, value: dotted quarter
# 434. Note 67 - Start: 433.0, Duration: 1.500, value: dotted quarter
# 435. Note 64 - Start: 434.5, Duration: 1.500, value: dotted quarter
# 436. Note 45 - Start: 435.0, Duration: 1.500, value: dotted quarter
# 437. Note 86 - Start: 438.5, Duration: 1.500, value: dotted quarter
# 438. Note 64 - Start: 443.0, Duration: 3.000, value: dotted half
# 439. Note 57 - Start: 444.0, Duration: 1.500, value: dotted quarter
# 440. Note 69 - Start: 444.0, Duration: 3.000, value: dotted half
# 441. Note 45 - Start: 444.0, Duration: 4.250, value: whole
# 442. Note 64 - Start: 445.0, Duration: 1.500, value: dotted quarter
# 443. Note 69 - Start: 445.5, Duration: 4.250, value: whole
# 444. Note 64 - Start: 446.0, Duration: 1.500, value: dotted quarter
# 445. Note 73 - Start: 446.0, Duration: 3.000, value: dotted half
# 446. Note 45 - Start: 447.5, Duration: 4.250, value: whole
# 447. Note 64 - Start: 448.0, Duration: 1.500, value: dotted quarter
# 448. Note 61 - Start: 448.0, Duration: 1.500, value: dotted quarter
# 449. Note 66 - Start: 451.5, Duration: 1.500, value: dotted quarter
# 450. Note 45 - Start: 451.5, Duration: 1.500, value: dotted quarter
# 451. Note 73 - Start: 454.5, Duration: 1.500, value: dotted quarter
# 452. Note 65 - Start: 455.0, Duration: 3.000, value: dotted half
# 453. Note 62 - Start: 455.0, Duration: 4.250, value: whole
# 454. Note 34 - Start: 456.0, Duration: 1.500, value: dotted quarter
# 455. Note 77 - Start: 456.0, Duration: 1.500, value: dotted quarter
# 456. Note 74 - Start: 456.0, Duration: 5.875, value: whole
# 457. Note 86 - Start: 456.0, Duration: 5.875, value: whole
# 458. Note 65 - Start: 457.0, Duration: 1.500, value: dotted quarter
# 459. Note 50 - Start: 463.5, Duration: 1.500, value: dotted quarter
# 460. Note 74 - Start: 463.5, Duration: 1.500, value: dotted quarter
# 461. Note 64 - Start: 464.0, Duration: 3.000, value: dotted half
# 462. Note 69 - Start: 464.5, Duration: 3.000, value: dotted half
# 463. Note 45 - Start: 464.5, Duration: 3.000, value: dotted half
# 464. Note 65 - Start: 466.5, Duration: 1.500, value: dotted quarter
# 465. Note 62 - Start: 466.5, Duration: 1.500, value: dotted quarter
# 466. Note 73 - Start: 468.5, Duration: 1.500, value: dotted quarter
# 467. Note 62 - Start: 470.5, Duration: 3.000, value: dotted half
# 468. Note 50 - Start: 471.5, Duration: 1.500, value: dotted quarter
# 469. Note 66 - Start: 471.5, Duration: 1.500, value: dotted quarter
# 470. Note 67 - Start: 475.0, Duration: 1.500, value: dotted quarter
# 471. Note 61 - Start: 476.0, Duration: 1.500, value: dotted quarter
# 472. Note 62 - Start: 478.0, Duration: 1.500, value: dotted quarter
# 473. Note 50 - Start: 480.5, Duration: 1.500, value: dotted quarter
# 474. Note 74 - Start: 480.5, Duration: 4.250, value: whole
# 475. Note 86 - Start: 481.0, Duration: 1.500, value: dotted quarter
# 476. Note 62 - Start: 483.0, Duration: 1.500, value: dotted quarter
# 477. Note 64 - Start: 484.0, Duration: 1.500, value: dotted quarter
# 478. Note 67 - Start: 484.0, Duration: 1.500, value: dotted quarter
# 479. Note 79 - Start: 484.0, Duration: 1.500, value: dotted quarter
# 480. Note 66 - Start: 485.0, Duration: 1.500, value: dotted quarter
# 481. Note 71 - Start: 485.5, Duration: 3.000, value: dotted half
# 482. Note 64 - Start: 488.5, Duration: 1.500, value: dotted quarter
# 483. Note 83 - Start: 488.5, Duration: 1.500, value: dotted quarter
# 484. Note 71 - Start: 490.0, Duration: 1.500, value: dotted quarter
# 485. Note 66 - Start: 494.5, Duration: 1.500, value: dotted quarter
# 486. Note 62 - Start: 494.5, Duration: 1.500, value: dotted quarter
# 487. Note 74 - Start: 496.0, Duration: 1.500, value: dotted quarter
# 488. Note 67 - Start: 496.0, Duration: 1.500, value: dotted quarter
# 489. Note 57 - Start: 496.5, Duration: 1.500, value: dotted quarter
# 490. Note 62 - Start: 497.5, Duration: 1.500, value: dotted quarter
# 491. Note 62 - Start: 499.0, Duration: 1.500, value: dotted quarter
# 492. Note 74 - Start: 500.0, Duration: 1.500, value: dotted quarter
# 493. Note 66 - Start: 502.5, Duration: 1.500, value: dotted quarter
# 494. Note 67 - Start: 503.0, Duration: 1.500, value: dotted quarter
# 495. Note 69 - Start: 504.5, Duration: 1.500, value: dotted quarter
# 496. Note 67 - Start: 507.0, Duration: 1.500, value: dotted quarter
# 497. Note 62 - Start: 509.5, Duration: 4.250, value: whole
# 498. Note 55 - Start: 510.0, Duration: 3.000, value: dotted half
# 499. Note 59 - Start: 510.0, Duration: 5.875, value: whole
# 500. Note 67 - Start: 510.5, Duration: 1.500, value: dotted quarter
# 501. Note 65 - Start: 513.0, Duration: 1.500, value: dotted quarter
# 502. Note 62 - Start: 514.5, Duration: 3.000, value: dotted half
# 503. Note 62 - Start: 517.5, Duration: 1.500, value: dotted quarter
# 504. Note 62 - Start: 519.5, Duration: 1.500, value: dotted quarter
# 505. Note 74 - Start: 521.0, Duration: 1.500, value: dotted quarter
# 506. Note 62 - Start: 521.0, Duration: 1.500, value: dotted quarter
# 507. Note 58 - Start: 521.5, Duration: 1.500, value: dotted quarter
# 508. Note 62 - Start: 522.5, Duration: 1.500, value: dotted quarter
# 509. Note 74 - Start: 525.0, Duration: 3.000, value: dotted half
# 510. Note 62 - Start: 526.5, Duration: 3.000, value: dotted half
# 511. Note 83 - Start: 533.5, Duration: 1.500, value: dotted quarter
# 512. Note 59 - Start: 533.5, Duration: 1.500, value: dotted quarter
# 513. Note 55 - Start: 533.5, Duration: 3.000, value: dotted half
# 514. Note 67 - Start: 534.0, Duration: 1.500, value: dotted quarter
# 515. Note 57 - Start: 535.0, Duration: 5.875, value: whole
# 516. Note 64 - Start: 536.5, Duration: 1.500, value: dotted quarter
# 517. Note 73 - Start: 536.5, Duration: 1.500, value: dotted quarter
# 518. Note 66 - Start: 537.0, Duration: 1.500, value: dotted quarter
# 519. Note 62 - Start: 537.0, Duration: 1.500, value: dotted quarter
# 520. Note 45 - Start: 537.5, Duration: 1.500, value: dotted quarter
# 521. Note 66 - Start: 540.5, Duration: 1.500, value: dotted quarter
# 522. Note 66 - Start: 545.5, Duration: 1.500, value: dotted quarter
# 523. Note 69 - Start: 545.5, Duration: 3.000, value: dotted half
# 524. Note 81 - Start: 546.0, Duration: 1.500, value: dotted quarter
# 525. Note 66 - Start: 546.5, Duration: 3.000, value: dotted half
# 526. Note 78 - Start: 547.0, Duration: 1.500, value: dotted quarter

# %%
notes_beat = process_notes(notes, tempo)

for idx, event in enumerate(sorted(notes_beat, key=lambda x: x["start_beat"])):
    print(f"{idx+1}. 🎵 Note {event['note']} - Start: {event['start_beat']:.1f}, Duration: {event['duration_beat']:.3f}, value: {event['note_value']}")
# Out:
# 1. 🎵 Note 62 - Start: 0.5, Duration: 1.750, value: half
# 2. 🎵 Note 50 - Start: 1.0, Duration: 1.250, value: tied quarter-sixteenth
# 3. 🎵 Note 66 - Start: 1.0, Duration: 1.250, value: tied quarter-sixteenth
# 4. 🎵 Note 69 - Start: 2.5, Duration: 0.625, value: quarter
# 5. 🎵 Note 69 - Start: 5.0, Duration: 0.625, value: quarter
# 6. 🎵 Note 62 - Start: 6.5, Duration: 0.625, value: quarter
# 7. 🎵 Note 66 - Start: 8.0, Duration: 0.625, value: quarter
# 8. 🎵 Note 73 - Start: 9.5, Duration: 0.625, value: quarter
# 9. 🎵 Note 66 - Start: 10.0, Duration: 0.625, value: quarter
# 10. 🎵 Note 62 - Start: 11.0, Duration: 0.625, value: quarter
# 11. 🎵 Note 74 - Start: 11.0, Duration: 1.250, value: tied quarter-sixteenth
# 12. 🎵 Note 86 - Start: 11.0, Duration: 1.250, value: tied quarter-sixteenth
# 13. 🎵 Note 62 - Start: 12.5, Duration: 0.625, value: quarter
# 14. 🎵 Note 64 - Start: 13.0, Duration: 0.625, value: quarter
# 15. 🎵 Note 45 - Start: 13.0, Duration: 1.250, value: tied quarter-sixteenth
# 16. 🎵 Note 67 - Start: 15.5, Duration: 0.625, value: quarter
# 17. 🎵 Note 86 - Start: 17.5, Duration: 0.625, value: quarter
# 18. 🎵 Note 57 - Start: 22.0, Duration: 0.625, value: quarter
# 19. 🎵 Note 45 - Start: 22.0, Duration: 1.250, value: tied quarter-sixteenth
# 20. 🎵 Note 64 - Start: 22.0, Duration: 1.750, value: half
# 21. 🎵 Note 73 - Start: 22.0, Duration: 1.750, value: half
# 22. 🎵 Note 69 - Start: 22.0, Duration: 1.750, value: half
# 23. 🎵 Note 62 - Start: 24.0, Duration: 2.375, value: half
# 24. 🎵 Note 66 - Start: 25.5, Duration: 1.250, value: tied quarter-sixteenth
# 25. 🎵 Note 67 - Start: 29.5, Duration: 0.625, value: quarter
# 26. 🎵 Note 62 - Start: 30.5, Duration: 0.625, value: quarter
# 27. 🎵 Note 61 - Start: 31.0, Duration: 0.625, value: quarter
# 28. 🎵 Note 62 - Start: 31.5, Duration: 0.625, value: quarter
# 29. 🎵 Note 50 - Start: 32.5, Duration: 0.625, value: quarter
# 30. 🎵 Note 64 - Start: 33.5, Duration: 0.625, value: quarter
# 31. 🎵 Note 66 - Start: 34.0, Duration: 0.625, value: quarter
# 32. 🎵 Note 86 - Start: 34.0, Duration: 0.625, value: quarter
# 33. 🎵 Note 62 - Start: 34.0, Duration: 1.250, value: tied quarter-sixteenth
# 34. 🎵 Note 74 - Start: 34.5, Duration: 1.250, value: tied quarter-sixteenth
# 35. 🎵 Note 86 - Start: 35.0, Duration: 0.625, value: quarter
# 36. 🎵 Note 64 - Start: 36.0, Duration: 0.625, value: quarter
# 37. 🎵 Note 73 - Start: 36.0, Duration: 0.625, value: quarter
# 38. 🎵 Note 67 - Start: 36.5, Duration: 0.625, value: quarter
# 39. 🎵 Note 45 - Start: 37.0, Duration: 1.250, value: tied quarter-sixteenth
# 40. 🎵 Note 66 - Start: 40.0, Duration: 1.250, value: tied quarter-sixteenth
# 41. 🎵 Note 86 - Start: 41.0, Duration: 0.625, value: quarter
# 42. 🎵 Note 64 - Start: 46.0, Duration: 1.250, value: tied quarter-sixteenth
# 43. 🎵 Note 73 - Start: 46.0, Duration: 1.250, value: tied quarter-sixteenth
# 44. 🎵 Note 57 - Start: 46.0, Duration: 1.250, value: tied quarter-sixteenth
# 45. 🎵 Note 69 - Start: 46.0, Duration: 1.750, value: half
# 46. 🎵 Note 45 - Start: 46.0, Duration: 1.750, value: half
# 47. 🎵 Note 69 - Start: 49.0, Duration: 0.625, value: quarter
# 48. 🎵 Note 73 - Start: 49.0, Duration: 1.250, value: tied quarter-sixteenth
# 49. 🎵 Note 45 - Start: 49.5, Duration: 1.250, value: tied quarter-sixteenth
# 50. 🎵 Note 64 - Start: 50.0, Duration: 0.625, value: quarter
# 51. 🎵 Note 66 - Start: 53.0, Duration: 0.625, value: quarter
# 52. 🎵 Note 45 - Start: 53.0, Duration: 1.750, value: half
# 53. 🎵 Note 57 - Start: 54.0, Duration: 0.625, value: quarter
# 54. 🎵 Note 64 - Start: 55.0, Duration: 0.625, value: quarter
# 55. 🎵 Note 73 - Start: 55.0, Duration: 0.625, value: quarter
# 56. 🎵 Note 45 - Start: 55.5, Duration: 1.750, value: half
# 57. 🎵 Note 62 - Start: 57.5, Duration: 1.250, value: tied quarter-sixteenth
# 58. 🎵 Note 65 - Start: 58.0, Duration: 1.750, value: half
# 59. 🎵 Note 74 - Start: 58.0, Duration: 1.750, value: half
# 60. 🎵 Note 86 - Start: 58.0, Duration: 1.750, value: half
# 61. 🎵 Note 53 - Start: 59.0, Duration: 0.625, value: quarter
# 62. 🎵 Note 58 - Start: 61.5, Duration: 0.625, value: quarter
# 63. 🎵 Note 73 - Start: 64.0, Duration: 0.625, value: quarter
# 64. 🎵 Note 74 - Start: 65.0, Duration: 0.625, value: quarter
# 65. 🎵 Note 53 - Start: 65.0, Duration: 0.625, value: quarter
# 66. 🎵 Note 86 - Start: 65.0, Duration: 0.625, value: quarter
# 67. 🎵 Note 64 - Start: 66.5, Duration: 0.625, value: quarter
# 68. 🎵 Note 73 - Start: 66.5, Duration: 0.625, value: quarter
# 69. 🎵 Note 45 - Start: 66.5, Duration: 1.250, value: tied quarter-sixteenth
# 70. 🎵 Note 69 - Start: 67.0, Duration: 0.625, value: quarter
# 71. 🎵 Note 65 - Start: 68.0, Duration: 1.250, value: tied quarter-sixteenth
# 72. 🎵 Note 62 - Start: 68.5, Duration: 0.625, value: quarter
# 73. 🎵 Note 61 - Start: 71.0, Duration: 0.625, value: quarter
# 74. 🎵 Note 62 - Start: 71.5, Duration: 1.250, value: tied quarter-sixteenth
# 75. 🎵 Note 66 - Start: 73.5, Duration: 0.625, value: quarter
# 76. 🎵 Note 67 - Start: 77.0, Duration: 0.625, value: quarter
# 77. 🎵 Note 62 - Start: 78.5, Duration: 0.625, value: quarter
# 78. 🎵 Note 61 - Start: 79.0, Duration: 0.625, value: quarter
# 79. 🎵 Note 65 - Start: 79.5, Duration: 0.625, value: quarter
# 80. 🎵 Note 66 - Start: 79.5, Duration: 0.625, value: quarter
# 81. 🎵 Note 50 - Start: 82.0, Duration: 1.250, value: tied quarter-sixteenth
# 82. 🎵 Note 62 - Start: 82.0, Duration: 1.250, value: tied quarter-sixteenth
# 83. 🎵 Note 74 - Start: 82.5, Duration: 1.250, value: tied quarter-sixteenth
# 84. 🎵 Note 86 - Start: 83.0, Duration: 0.625, value: quarter
# 85. 🎵 Note 64 - Start: 85.0, Duration: 0.625, value: quarter
# 86. 🎵 Note 79 - Start: 85.0, Duration: 0.625, value: quarter
# 87. 🎵 Note 67 - Start: 85.0, Duration: 2.375, value: half
# 88. 🎵 Note 57 - Start: 95.5, Duration: 0.625, value: quarter
# 89. 🎵 Note 67 - Start: 98.0, Duration: 0.625, value: quarter
# 90. 🎵 Note 64 - Start: 98.5, Duration: 0.625, value: quarter
# 91. 🎵 Note 73 - Start: 98.5, Duration: 1.250, value: tied quarter-sixteenth
# 92. 🎵 Note 57 - Start: 98.5, Duration: 1.250, value: tied quarter-sixteenth
# 93. 🎵 Note 50 - Start: 100.0, Duration: 1.250, value: tied quarter-sixteenth
# 94. 🎵 Note 74 - Start: 100.0, Duration: 1.250, value: tied quarter-sixteenth
# 95. 🎵 Note 62 - Start: 100.0, Duration: 1.750, value: half
# 96. 🎵 Note 74 - Start: 101.5, Duration: 1.250, value: tied quarter-sixteenth
# 97. 🎵 Note 66 - Start: 104.0, Duration: 1.250, value: tied quarter-sixteenth
# 98. 🎵 Note 67 - Start: 104.5, Duration: 1.250, value: tied quarter-sixteenth
# 99. 🎵 Note 69 - Start: 106.5, Duration: 1.250, value: tied quarter-sixteenth
# 100. 🎵 Note 66 - Start: 107.5, Duration: 0.625, value: quarter
# 101. 🎵 Note 78 - Start: 107.5, Duration: 0.625, value: quarter
# 102. 🎵 Note 64 - Start: 108.5, Duration: 0.625, value: quarter
# 103. 🎵 Note 62 - Start: 110.5, Duration: 1.750, value: half
# 104. 🎵 Note 59 - Start: 111.5, Duration: 1.250, value: tied quarter-sixteenth
# 105. 🎵 Note 55 - Start: 111.5, Duration: 1.250, value: tied quarter-sixteenth
# 106. 🎵 Note 67 - Start: 112.5, Duration: 0.625, value: quarter
# 107. 🎵 Note 56 - Start: 114.5, Duration: 0.625, value: quarter
# 108. 🎵 Note 65 - Start: 114.5, Duration: 0.625, value: quarter
# 109. 🎵 Note 61 - Start: 115.5, Duration: 0.625, value: quarter
# 110. 🎵 Note 62 - Start: 115.5, Duration: 1.750, value: half
# 111. 🎵 Note 61 - Start: 118.5, Duration: 0.625, value: quarter
# 112. 🎵 Note 62 - Start: 119.0, Duration: 1.250, value: tied quarter-sixteenth
# 113. 🎵 Note 65 - Start: 119.5, Duration: 0.625, value: quarter
# 114. 🎵 Note 74 - Start: 120.5, Duration: 1.250, value: tied quarter-sixteenth
# 115. 🎵 Note 58 - Start: 121.5, Duration: 0.625, value: quarter
# 116. 🎵 Note 62 - Start: 121.5, Duration: 2.375, value: half
# 117. 🎵 Note 58 - Start: 122.5, Duration: 1.250, value: tied quarter-sixteenth
# 118. 🎵 Note 74 - Start: 123.0, Duration: 0.625, value: quarter
# 119. 🎵 Note 59 - Start: 124.0, Duration: 0.625, value: quarter
# 120. 🎵 Note 62 - Start: 124.0, Duration: 1.750, value: half
# 121. 🎵 Note 78 - Start: 125.5, Duration: 0.625, value: quarter
# 122. 🎵 Note 74 - Start: 126.5, Duration: 0.625, value: quarter
# 123. 🎵 Note 62 - Start: 128.0, Duration: 1.250, value: tied quarter-sixteenth
# 124. 🎵 Note 78 - Start: 129.0, Duration: 0.625, value: quarter
# 125. 🎵 Note 59 - Start: 134.0, Duration: 1.250, value: tied quarter-sixteenth
# 126. 🎵 Note 83 - Start: 134.5, Duration: 0.625, value: quarter
# 127. 🎵 Note 67 - Start: 135.0, Duration: 0.625, value: quarter
# 128. 🎵 Note 57 - Start: 136.0, Duration: 1.250, value: tied quarter-sixteenth
# 129. 🎵 Note 66 - Start: 137.0, Duration: 0.625, value: quarter
# 130. 🎵 Note 86 - Start: 138.0, Duration: 0.625, value: quarter
# 131. 🎵 Note 74 - Start: 138.0, Duration: 0.625, value: quarter
# 132. 🎵 Note 62 - Start: 138.0, Duration: 0.625, value: quarter
# 133. 🎵 Note 66 - Start: 141.5, Duration: 0.625, value: quarter
# 134. 🎵 Note 38 - Start: 144.0, Duration: 0.625, value: quarter
# 135. 🎵 Note 66 - Start: 146.5, Duration: 0.625, value: quarter
# 136. 🎵 Note 81 - Start: 147.0, Duration: 0.625, value: quarter
# 137. 🎵 Note 69 - Start: 147.0, Duration: 0.625, value: quarter
# 138. 🎵 Note 66 - Start: 147.5, Duration: 0.625, value: quarter
# 139. 🎵 Note 78 - Start: 147.5, Duration: 0.625, value: quarter
# 140. 🎵 Note 66 - Start: 148.5, Duration: 0.625, value: quarter
# 141. 🎵 Note 69 - Start: 151.0, Duration: 0.625, value: quarter
# 142. 🎵 Note 73 - Start: 151.0, Duration: 1.750, value: half
# 143. 🎵 Note 45 - Start: 151.0, Duration: 3.000, value: dotted half
# 144. 🎵 Note 64 - Start: 151.5, Duration: 1.750, value: half
# 145. 🎵 Note 69 - Start: 153.5, Duration: 0.625, value: quarter
# 146. 🎵 Note 45 - Start: 156.0, Duration: 3.000, value: dotted half
# 147. 🎵 Note 57 - Start: 156.5, Duration: 0.625, value: quarter
# 148. 🎵 Note 64 - Start: 156.5, Duration: 1.750, value: half
# 149. 🎵 Note 57 - Start: 158.5, Duration: 0.625, value: quarter
# 150. 🎵 Note 64 - Start: 159.0, Duration: 0.625, value: quarter
# 151. 🎵 Note 73 - Start: 159.5, Duration: 0.625, value: quarter
# 152. 🎵 Note 62 - Start: 160.0, Duration: 0.625, value: quarter
# 153. 🎵 Note 58 - Start: 160.5, Duration: 0.625, value: quarter
# 154. 🎵 Note 74 - Start: 160.5, Duration: 2.375, value: half
# 155. 🎵 Note 62 - Start: 161.5, Duration: 1.250, value: tied quarter-sixteenth
# 156. 🎵 Note 86 - Start: 161.5, Duration: 1.750, value: half
# 157. 🎵 Note 53 - Start: 162.0, Duration: 0.625, value: quarter
# 158. 🎵 Note 65 - Start: 162.0, Duration: 1.250, value: tied quarter-sixteenth
# 159. 🎵 Note 64 - Start: 164.5, Duration: 0.625, value: quarter
# 160. 🎵 Note 58 - Start: 164.5, Duration: 0.625, value: quarter
# 161. 🎵 Note 88 - Start: 164.5, Duration: 0.625, value: quarter
# 162. 🎵 Note 73 - Start: 166.5, Duration: 0.625, value: quarter
# 163. 🎵 Note 62 - Start: 168.5, Duration: 0.625, value: quarter
# 164. 🎵 Note 50 - Start: 168.5, Duration: 0.625, value: quarter
# 165. 🎵 Note 74 - Start: 168.5, Duration: 0.625, value: quarter
# 166. 🎵 Note 86 - Start: 168.5, Duration: 0.625, value: quarter
# 167. 🎵 Note 45 - Start: 169.5, Duration: 1.250, value: tied quarter-sixteenth
# 168. 🎵 Note 69 - Start: 169.5, Duration: 1.750, value: half
# 169. 🎵 Note 73 - Start: 170.0, Duration: 0.625, value: quarter
# 170. 🎵 Note 64 - Start: 170.0, Duration: 1.250, value: tied quarter-sixteenth
# 171. 🎵 Note 65 - Start: 171.5, Duration: 0.625, value: quarter
# 172. 🎵 Note 62 - Start: 171.5, Duration: 1.250, value: tied quarter-sixteenth
# 173. 🎵 Note 73 - Start: 173.0, Duration: 1.750, value: half
# 174. 🎵 Note 64 - Start: 174.5, Duration: 0.625, value: quarter
# 175. 🎵 Note 62 - Start: 175.5, Duration: 1.250, value: tied quarter-sixteenth
# 176. 🎵 Note 66 - Start: 176.0, Duration: 1.250, value: tied quarter-sixteenth
# 177. 🎵 Note 62 - Start: 181.5, Duration: 0.625, value: quarter
# 178. 🎵 Note 66 - Start: 183.0, Duration: 0.625, value: quarter
# 179. 🎵 Note 62 - Start: 183.0, Duration: 0.625, value: quarter
# 180. 🎵 Note 50 - Start: 185.0, Duration: 0.625, value: quarter
# 181. 🎵 Note 74 - Start: 185.0, Duration: 0.625, value: quarter
# 182. 🎵 Note 86 - Start: 185.0, Duration: 0.625, value: quarter
# 183. 🎵 Note 62 - Start: 185.0, Duration: 1.750, value: half
# 184. 🎵 Note 74 - Start: 186.5, Duration: 0.625, value: quarter
# 185. 🎵 Note 86 - Start: 186.5, Duration: 0.625, value: quarter
# 186. 🎵 Note 67 - Start: 188.0, Duration: 0.625, value: quarter
# 187. 🎵 Note 64 - Start: 189.5, Duration: 0.625, value: quarter
# 188. 🎵 Note 67 - Start: 189.5, Duration: 0.625, value: quarter
# 189. 🎵 Note 79 - Start: 189.5, Duration: 0.625, value: quarter
# 190. 🎵 Note 74 - Start: 194.0, Duration: 0.625, value: quarter
# 191. 🎵 Note 83 - Start: 194.0, Duration: 0.625, value: quarter
# 192. 🎵 Note 57 - Start: 199.0, Duration: 0.625, value: quarter
# 193. 🎵 Note 62 - Start: 200.0, Duration: 0.625, value: quarter
# 194. 🎵 Note 50 - Start: 200.0, Duration: 0.625, value: quarter
# 195. 🎵 Note 66 - Start: 200.0, Duration: 0.625, value: quarter
# 196. 🎵 Note 78 - Start: 200.0, Duration: 0.625, value: quarter
# 197. 🎵 Note 62 - Start: 203.0, Duration: 1.750, value: half
# 198. 🎵 Note 74 - Start: 203.5, Duration: 1.250, value: tied quarter-sixteenth
# 199. 🎵 Note 50 - Start: 204.5, Duration: 0.625, value: quarter
# 200. 🎵 Note 74 - Start: 205.5, Duration: 1.250, value: tied quarter-sixteenth
# 201. 🎵 Note 66 - Start: 208.0, Duration: 0.625, value: quarter
# 202. 🎵 Note 67 - Start: 208.0, Duration: 1.750, value: half
# 203. 🎵 Note 64 - Start: 209.0, Duration: 0.625, value: quarter
# 204. 🎵 Note 66 - Start: 211.5, Duration: 0.625, value: quarter
# 205. 🎵 Note 67 - Start: 212.5, Duration: 0.625, value: quarter
# 206. 🎵 Note 68 - Start: 214.0, Duration: 0.625, value: quarter
# 207. 🎵 Note 69 - Start: 214.5, Duration: 0.625, value: quarter
# 208. 🎵 Note 62 - Start: 214.5, Duration: 1.750, value: half
# 209. 🎵 Note 59 - Start: 215.5, Duration: 3.000, value: dotted half
# 210. 🎵 Note 67 - Start: 216.0, Duration: 0.625, value: quarter
# 211. 🎵 Note 55 - Start: 216.0, Duration: 0.625, value: quarter
# 212. 🎵 Note 83 - Start: 218.5, Duration: 0.625, value: quarter
# 213. 🎵 Note 56 - Start: 219.0, Duration: 0.625, value: quarter
# 214. 🎵 Note 62 - Start: 220.5, Duration: 0.625, value: quarter
# 215. 🎵 Note 62 - Start: 223.0, Duration: 1.250, value: tied quarter-sixteenth
# 216. 🎵 Note 58 - Start: 224.5, Duration: 1.250, value: tied quarter-sixteenth
# 217. 🎵 Note 74 - Start: 224.5, Duration: 1.250, value: tied quarter-sixteenth
# 218. 🎵 Note 62 - Start: 226.0, Duration: 1.750, value: half
# 219. 🎵 Note 58 - Start: 226.5, Duration: 1.250, value: tied quarter-sixteenth
# 220. 🎵 Note 74 - Start: 227.0, Duration: 0.625, value: quarter
# 221. 🎵 Note 62 - Start: 229.0, Duration: 1.250, value: tied quarter-sixteenth
# 222. 🎵 Note 74 - Start: 230.5, Duration: 0.625, value: quarter
# 223. 🎵 Note 62 - Start: 232.0, Duration: 0.625, value: quarter
# 224. 🎵 Note 59 - Start: 237.5, Duration: 0.625, value: quarter
# 225. 🎵 Note 79 - Start: 237.5, Duration: 0.625, value: quarter
# 226. 🎵 Note 67 - Start: 238.5, Duration: 0.625, value: quarter
# 227. 🎵 Note 55 - Start: 238.5, Duration: 1.750, value: half
# 228. 🎵 Note 59 - Start: 239.0, Duration: 0.625, value: quarter
# 229. 🎵 Note 83 - Start: 239.0, Duration: 0.625, value: quarter
# 230. 🎵 Note 64 - Start: 239.5, Duration: 0.625, value: quarter
# 231. 🎵 Note 67 - Start: 239.5, Duration: 0.625, value: quarter
# 232. 🎵 Note 74 - Start: 240.5, Duration: 0.625, value: quarter
# 233. 🎵 Note 66 - Start: 240.5, Duration: 1.250, value: tied quarter-sixteenth
# 234. 🎵 Note 57 - Start: 240.5, Duration: 2.375, value: half
# 235. 🎵 Note 66 - Start: 242.5, Duration: 0.625, value: quarter
# 236. 🎵 Note 62 - Start: 242.5, Duration: 0.625, value: quarter
# 237. 🎵 Note 66 - Start: 246.0, Duration: 0.625, value: quarter
# 238. 🎵 Note 66 - Start: 251.0, Duration: 0.625, value: quarter
# 239. 🎵 Note 69 - Start: 251.5, Duration: 0.625, value: quarter
# 240. 🎵 Note 66 - Start: 252.5, Duration: 1.250, value: tied quarter-sixteenth
# 241. 🎵 Note 61 - Start: 255.0, Duration: 0.625, value: quarter
# 242. 🎵 Note 65 - Start: 258.0, Duration: 0.625, value: quarter
# 243. 🎵 Note 68 - Start: 258.0, Duration: 0.625, value: quarter
# 244. 🎵 Note 62 - Start: 258.0, Duration: 0.625, value: quarter
# 245. 🎵 Note 61 - Start: 259.0, Duration: 1.250, value: tied quarter-sixteenth
# 246. 🎵 Note 69 - Start: 260.0, Duration: 0.625, value: quarter
# 247. 🎵 Note 59 - Start: 261.5, Duration: 0.625, value: quarter
# 248. 🎵 Note 67 - Start: 261.5, Duration: 1.750, value: half
# 249. 🎵 Note 66 - Start: 262.0, Duration: 1.250, value: tied quarter-sixteenth
# 250. 🎵 Note 59 - Start: 263.0, Duration: 0.625, value: quarter
# 251. 🎵 Note 62 - Start: 263.5, Duration: 0.625, value: quarter
# 252. 🎵 Note 64 - Start: 264.0, Duration: 0.625, value: quarter
# 253. 🎵 Note 58 - Start: 264.0, Duration: 0.625, value: quarter
# 254. 🎵 Note 57 - Start: 264.5, Duration: 1.750, value: half
# 255. 🎵 Note 64 - Start: 267.0, Duration: 0.625, value: quarter
# 256. 🎵 Note 60 - Start: 267.0, Duration: 0.625, value: quarter
# 257. 🎵 Note 65 - Start: 267.5, Duration: 1.250, value: tied quarter-sixteenth
# 258. 🎵 Note 57 - Start: 267.5, Duration: 1.250, value: tied quarter-sixteenth
# 259. 🎵 Note 69 - Start: 268.0, Duration: 0.625, value: quarter
# 260. 🎵 Note 65 - Start: 269.5, Duration: 0.625, value: quarter
# 261. 🎵 Note 72 - Start: 270.5, Duration: 1.250, value: tied quarter-sixteenth
# 262. 🎵 Note 72 - Start: 273.5, Duration: 0.625, value: quarter
# 263. 🎵 Note 77 - Start: 274.0, Duration: 0.625, value: quarter
# 264. 🎵 Note 69 - Start: 274.0, Duration: 0.625, value: quarter
# 265. 🎵 Note 84 - Start: 275.0, Duration: 1.250, value: tied quarter-sixteenth
# 266. 🎵 Note 72 - Start: 275.5, Duration: 0.625, value: quarter
# 267. 🎵 Note 82 - Start: 275.5, Duration: 0.625, value: quarter
# 268. 🎵 Note 60 - Start: 275.5, Duration: 0.625, value: quarter
# 269. 🎵 Note 81 - Start: 276.0, Duration: 0.625, value: quarter
# 270. 🎵 Note 65 - Start: 276.0, Duration: 0.625, value: quarter
# 271. 🎵 Note 53 - Start: 276.0, Duration: 0.625, value: quarter
# 272. 🎵 Note 70 - Start: 278.0, Duration: 1.250, value: tied quarter-sixteenth
# 273. 🎵 Note 82 - Start: 278.0, Duration: 1.250, value: tied quarter-sixteenth
# 274. 🎵 Note 72 - Start: 278.5, Duration: 0.625, value: quarter
# 275. 🎵 Note 84 - Start: 278.5, Duration: 0.625, value: quarter
# 276. 🎵 Note 60 - Start: 278.5, Duration: 0.625, value: quarter
# 277. 🎵 Note 81 - Start: 279.0, Duration: 0.625, value: quarter
# 278. 🎵 Note 65 - Start: 279.0, Duration: 0.625, value: quarter
# 279. 🎵 Note 53 - Start: 279.0, Duration: 0.625, value: quarter
# 280. 🎵 Note 70 - Start: 279.5, Duration: 0.625, value: quarter
# 281. 🎵 Note 65 - Start: 280.0, Duration: 0.625, value: quarter
# 282. 🎵 Note 70 - Start: 280.5, Duration: 0.625, value: quarter
# 283. 🎵 Note 82 - Start: 280.5, Duration: 1.250, value: tied quarter-sixteenth
# 284. 🎵 Note 69 - Start: 282.0, Duration: 0.625, value: quarter
# 285. 🎵 Note 65 - Start: 282.5, Duration: 0.625, value: quarter
# 286. 🎵 Note 69 - Start: 283.0, Duration: 0.625, value: quarter
# 287. 🎵 Note 65 - Start: 285.0, Duration: 0.625, value: quarter
# 288. 🎵 Note 70 - Start: 287.5, Duration: 0.625, value: quarter
# 289. 🎵 Note 58 - Start: 287.5, Duration: 0.625, value: quarter
# 290. 🎵 Note 62 - Start: 287.5, Duration: 0.625, value: quarter
# 291. 🎵 Note 50 - Start: 287.5, Duration: 1.250, value: tied quarter-sixteenth
# 292. 🎵 Note 70 - Start: 288.5, Duration: 0.625, value: quarter
# 293. 🎵 Note 70 - Start: 289.5, Duration: 0.625, value: quarter
# 294. 🎵 Note 69 - Start: 290.5, Duration: 0.625, value: quarter
# 295. 🎵 Note 48 - Start: 290.5, Duration: 2.375, value: half
# 296. 🎵 Note 70 - Start: 291.0, Duration: 0.625, value: quarter
# 297. 🎵 Note 65 - Start: 293.5, Duration: 1.250, value: tied quarter-sixteenth
# 298. 🎵 Note 41 - Start: 293.5, Duration: 1.250, value: tied quarter-sixteenth
# 299. 🎵 Note 69 - Start: 297.5, Duration: 0.625, value: quarter
# 300. 🎵 Note 62 - Start: 298.0, Duration: 0.625, value: quarter
# 301. 🎵 Note 68 - Start: 298.5, Duration: 1.250, value: tied quarter-sixteenth
# 302. 🎵 Note 61 - Start: 299.5, Duration: 1.750, value: half
# 303. 🎵 Note 64 - Start: 300.5, Duration: 0.625, value: quarter
# 304. 🎵 Note 66 - Start: 301.5, Duration: 1.250, value: tied quarter-sixteenth
# 305. 🎵 Note 67 - Start: 301.5, Duration: 2.375, value: half
# 306. 🎵 Note 59 - Start: 302.5, Duration: 1.750, value: half
# 307. 🎵 Note 86 - Start: 303.0, Duration: 0.625, value: quarter
# 308. 🎵 Note 62 - Start: 303.5, Duration: 0.625, value: quarter
# 309. 🎵 Note 58 - Start: 304.0, Duration: 0.625, value: quarter
# 310. 🎵 Note 57 - Start: 304.5, Duration: 1.750, value: half
# 311. 🎵 Note 65 - Start: 306.0, Duration: 0.625, value: quarter
# 312. 🎵 Note 64 - Start: 307.0, Duration: 0.625, value: quarter
# 313. 🎵 Note 57 - Start: 307.5, Duration: 0.625, value: quarter
# 314. 🎵 Note 65 - Start: 307.5, Duration: 2.375, value: half
# 315. 🎵 Note 69 - Start: 308.0, Duration: 0.625, value: quarter
# 316. 🎵 Note 71 - Start: 310.0, Duration: 0.625, value: quarter
# 317. 🎵 Note 64 - Start: 310.5, Duration: 1.250, value: tied quarter-sixteenth
# 318. 🎵 Note 72 - Start: 310.5, Duration: 1.250, value: tied quarter-sixteenth
# 319. 🎵 Note 72 - Start: 313.0, Duration: 0.625, value: quarter
# 320. 🎵 Note 72 - Start: 315.0, Duration: 1.250, value: tied quarter-sixteenth
# 321. 🎵 Note 82 - Start: 315.5, Duration: 0.625, value: quarter
# 322. 🎵 Note 84 - Start: 315.5, Duration: 0.625, value: quarter
# 323. 🎵 Note 53 - Start: 316.0, Duration: 0.625, value: quarter
# 324. 🎵 Note 84 - Start: 317.0, Duration: 0.625, value: quarter
# 325. 🎵 Note 53 - Start: 317.0, Duration: 0.625, value: quarter
# 326. 🎵 Note 72 - Start: 318.0, Duration: 1.250, value: tied quarter-sixteenth
# 327. 🎵 Note 70 - Start: 318.5, Duration: 0.625, value: quarter
# 328. 🎵 Note 82 - Start: 318.5, Duration: 1.250, value: tied quarter-sixteenth
# 329. 🎵 Note 65 - Start: 319.0, Duration: 0.625, value: quarter
# 330. 🎵 Note 81 - Start: 319.0, Duration: 0.625, value: quarter
# 331. 🎵 Note 53 - Start: 319.0, Duration: 0.625, value: quarter
# 332. 🎵 Note 53 - Start: 320.0, Duration: 0.625, value: quarter
# 333. 🎵 Note 70 - Start: 321.0, Duration: 0.625, value: quarter
# 334. 🎵 Note 82 - Start: 321.0, Duration: 1.250, value: tied quarter-sixteenth
# 335. 🎵 Note 72 - Start: 321.5, Duration: 0.625, value: quarter
# 336. 🎵 Note 60 - Start: 321.5, Duration: 0.625, value: quarter
# 337. 🎵 Note 53 - Start: 322.0, Duration: 0.625, value: quarter
# 338. 🎵 Note 65 - Start: 322.0, Duration: 1.250, value: tied quarter-sixteenth
# 339. 🎵 Note 69 - Start: 323.0, Duration: 0.625, value: quarter
# 340. 🎵 Note 53 - Start: 324.5, Duration: 0.625, value: quarter
# 341. 🎵 Note 65 - Start: 325.0, Duration: 1.250, value: tied quarter-sixteenth
# 342. 🎵 Note 69 - Start: 327.5, Duration: 0.625, value: quarter
# 343. 🎵 Note 81 - Start: 327.5, Duration: 1.250, value: tied quarter-sixteenth
# 344. 🎵 Note 70 - Start: 327.5, Duration: 1.750, value: half
# 345. 🎵 Note 50 - Start: 328.0, Duration: 0.625, value: quarter
# 346. 🎵 Note 81 - Start: 330.5, Duration: 0.625, value: quarter
# 347. 🎵 Note 65 - Start: 330.5, Duration: 0.625, value: quarter
# 348. 🎵 Note 48 - Start: 330.5, Duration: 1.250, value: tied quarter-sixteenth
# 349. 🎵 Note 69 - Start: 330.5, Duration: 1.250, value: tied quarter-sixteenth
# 350. 🎵 Note 48 - Start: 332.0, Duration: 0.625, value: quarter
# 351. 🎵 Note 57 - Start: 333.5, Duration: 1.250, value: tied quarter-sixteenth
# 352. 🎵 Note 41 - Start: 333.5, Duration: 1.250, value: tied quarter-sixteenth
# 353. 🎵 Note 65 - Start: 333.5, Duration: 1.750, value: half
# 354. 🎵 Note 53 - Start: 333.5, Duration: 1.750, value: half
# 355. 🎵 Note 62 - Start: 335.5, Duration: 0.625, value: quarter
# 356. 🎵 Note 64 - Start: 336.5, Duration: 0.625, value: quarter
# 357. 🎵 Note 79 - Start: 336.5, Duration: 0.625, value: quarter
# 358. 🎵 Note 64 - Start: 340.0, Duration: 0.625, value: quarter
# 359. 🎵 Note 57 - Start: 340.5, Duration: 0.625, value: quarter
# 360. 🎵 Note 67 - Start: 342.5, Duration: 1.250, value: tied quarter-sixteenth
# 361. 🎵 Note 61 - Start: 346.5, Duration: 0.625, value: quarter
# 362. 🎵 Note 58 - Start: 349.5, Duration: 0.625, value: quarter
# 363. 🎵 Note 56 - Start: 350.0, Duration: 0.625, value: quarter
# 364. 🎵 Note 65 - Start: 350.0, Duration: 0.625, value: quarter
# 365. 🎵 Note 74 - Start: 350.0, Duration: 0.625, value: quarter
# 366. 🎵 Note 62 - Start: 354.0, Duration: 0.625, value: quarter
# 367. 🎵 Note 70 - Start: 355.5, Duration: 0.625, value: quarter
# 368. 🎵 Note 53 - Start: 356.5, Duration: 0.625, value: quarter
# 369. 🎵 Note 65 - Start: 358.5, Duration: 0.625, value: quarter
# 370. 🎵 Note 62 - Start: 358.5, Duration: 0.625, value: quarter
# 371. 🎵 Note 62 - Start: 359.5, Duration: 0.625, value: quarter
# 372. 🎵 Note 74 - Start: 360.0, Duration: 0.625, value: quarter
# 373. 🎵 Note 57 - Start: 362.5, Duration: 0.625, value: quarter
# 374. 🎵 Note 62 - Start: 362.5, Duration: 1.250, value: tied quarter-sixteenth
# 375. 🎵 Note 66 - Start: 362.5, Duration: 1.250, value: tied quarter-sixteenth
# 376. 🎵 Note 50 - Start: 362.5, Duration: 1.250, value: tied quarter-sixteenth
# 377. 🎵 Note 38 - Start: 362.5, Duration: 1.250, value: tied quarter-sixteenth
# 378. 🎵 Note 81 - Start: 365.0, Duration: 0.625, value: quarter
# 379. 🎵 Note 62 - Start: 365.0, Duration: 0.625, value: quarter
# 380. 🎵 Note 64 - Start: 365.5, Duration: 0.625, value: quarter
# 381. 🎵 Note 57 - Start: 365.5, Duration: 0.625, value: quarter
# 382. 🎵 Note 79 - Start: 365.5, Duration: 0.625, value: quarter
# 383. 🎵 Note 67 - Start: 367.0, Duration: 0.625, value: quarter
# 384. 🎵 Note 74 - Start: 368.0, Duration: 0.625, value: quarter
# 385. 🎵 Note 77 - Start: 368.0, Duration: 0.625, value: quarter
# 386. 🎵 Note 67 - Start: 368.0, Duration: 1.250, value: tied quarter-sixteenth
# 387. 🎵 Note 57 - Start: 369.5, Duration: 0.625, value: quarter
# 388. 🎵 Note 64 - Start: 371.5, Duration: 0.625, value: quarter
# 389. 🎵 Note 67 - Start: 373.5, Duration: 1.250, value: tied quarter-sixteenth
# 390. 🎵 Note 61 - Start: 375.0, Duration: 0.625, value: quarter
# 391. 🎵 Note 62 - Start: 375.0, Duration: 1.250, value: tied quarter-sixteenth
# 392. 🎵 Note 74 - Start: 378.5, Duration: 0.625, value: quarter
# 393. 🎵 Note 62 - Start: 383.5, Duration: 0.625, value: quarter
# 394. 🎵 Note 45 - Start: 386.5, Duration: 0.625, value: quarter
# 395. 🎵 Note 57 - Start: 387.0, Duration: 0.625, value: quarter
# 396. 🎵 Note 65 - Start: 388.5, Duration: 0.625, value: quarter
# 397. 🎵 Note 61 - Start: 392.0, Duration: 1.250, value: tied quarter-sixteenth
# 398. 🎵 Note 45 - Start: 392.0, Duration: 1.250, value: tied quarter-sixteenth
# 399. 🎵 Note 64 - Start: 392.5, Duration: 0.625, value: quarter
# 400. 🎵 Note 73 - Start: 392.5, Duration: 0.625, value: quarter
# 401. 🎵 Note 57 - Start: 392.5, Duration: 2.375, value: half
# 402. 🎵 Note 50 - Start: 393.0, Duration: 1.750, value: half
# 403. 🎵 Note 62 - Start: 393.0, Duration: 2.375, value: half
# 404. 🎵 Note 66 - Start: 393.0, Duration: 3.000, value: dotted half
# 405. 🎵 Note 38 - Start: 393.5, Duration: 1.750, value: half
# 406. 🎵 Note 62 - Start: 398.0, Duration: 1.250, value: tied quarter-sixteenth
# 407. 🎵 Note 66 - Start: 398.0, Duration: 1.750, value: half
# 408. 🎵 Note 50 - Start: 398.5, Duration: 1.750, value: half
# 409. 🎵 Note 62 - Start: 399.5, Duration: 0.625, value: quarter
# 410. 🎵 Note 67 - Start: 402.0, Duration: 0.625, value: quarter
# 411. 🎵 Note 61 - Start: 403.0, Duration: 0.625, value: quarter
# 412. 🎵 Note 62 - Start: 404.0, Duration: 0.625, value: quarter
# 413. 🎵 Note 50 - Start: 406.0, Duration: 0.625, value: quarter
# 414. 🎵 Note 74 - Start: 407.5, Duration: 1.250, value: tied quarter-sixteenth
# 415. 🎵 Note 62 - Start: 407.5, Duration: 1.250, value: tied quarter-sixteenth
# 416. 🎵 Note 86 - Start: 407.5, Duration: 1.750, value: half
# 417. 🎵 Note 67 - Start: 409.0, Duration: 0.625, value: quarter
# 418. 🎵 Note 61 - Start: 410.0, Duration: 0.625, value: quarter
# 419. 🎵 Note 45 - Start: 410.0, Duration: 1.750, value: half
# 420. 🎵 Note 66 - Start: 413.5, Duration: 0.625, value: quarter
# 421. 🎵 Note 62 - Start: 413.5, Duration: 0.625, value: quarter
# 422. 🎵 Note 73 - Start: 419.5, Duration: 0.625, value: quarter
# 423. 🎵 Note 64 - Start: 419.5, Duration: 1.750, value: half
# 424. 🎵 Note 45 - Start: 419.5, Duration: 1.750, value: half
# 425. 🎵 Note 69 - Start: 420.0, Duration: 0.625, value: quarter
# 426. 🎵 Note 62 - Start: 421.5, Duration: 1.750, value: half
# 427. 🎵 Note 50 - Start: 423.0, Duration: 0.625, value: quarter
# 428. 🎵 Note 57 - Start: 423.0, Duration: 1.250, value: tied quarter-sixteenth
# 429. 🎵 Note 66 - Start: 423.5, Duration: 0.625, value: quarter
# 430. 🎵 Note 62 - Start: 429.0, Duration: 1.250, value: tied quarter-sixteenth
# 431. 🎵 Note 50 - Start: 429.5, Duration: 0.625, value: quarter
# 432. 🎵 Note 66 - Start: 432.0, Duration: 0.625, value: quarter
# 433. 🎵 Note 74 - Start: 432.5, Duration: 0.625, value: quarter
# 434. 🎵 Note 67 - Start: 433.0, Duration: 0.625, value: quarter
# 435. 🎵 Note 64 - Start: 434.5, Duration: 0.625, value: quarter
# 436. 🎵 Note 45 - Start: 435.0, Duration: 0.625, value: quarter
# 437. 🎵 Note 86 - Start: 438.5, Duration: 0.625, value: quarter
# 438. 🎵 Note 64 - Start: 443.0, Duration: 1.250, value: tied quarter-sixteenth
# 439. 🎵 Note 57 - Start: 444.0, Duration: 0.625, value: quarter
# 440. 🎵 Note 69 - Start: 444.0, Duration: 1.250, value: tied quarter-sixteenth
# 441. 🎵 Note 45 - Start: 444.0, Duration: 1.750, value: half
# 442. 🎵 Note 64 - Start: 445.0, Duration: 0.625, value: quarter
# 443. 🎵 Note 69 - Start: 445.5, Duration: 1.750, value: half
# 444. 🎵 Note 64 - Start: 446.0, Duration: 0.625, value: quarter
# 445. 🎵 Note 73 - Start: 446.0, Duration: 1.250, value: tied quarter-sixteenth
# 446. 🎵 Note 45 - Start: 447.5, Duration: 1.750, value: half
# 447. 🎵 Note 64 - Start: 448.0, Duration: 0.625, value: quarter
# 448. 🎵 Note 61 - Start: 448.0, Duration: 0.625, value: quarter
# 449. 🎵 Note 66 - Start: 451.5, Duration: 0.625, value: quarter
# 450. 🎵 Note 45 - Start: 451.5, Duration: 0.625, value: quarter
# 451. 🎵 Note 73 - Start: 454.5, Duration: 0.625, value: quarter
# 452. 🎵 Note 65 - Start: 455.0, Duration: 1.250, value: tied quarter-sixteenth
# 453. 🎵 Note 62 - Start: 455.0, Duration: 1.750, value: half
# 454. 🎵 Note 34 - Start: 456.0, Duration: 0.625, value: quarter
# 455. 🎵 Note 77 - Start: 456.0, Duration: 0.625, value: quarter
# 456. 🎵 Note 74 - Start: 456.0, Duration: 2.375, value: half
# 457. 🎵 Note 86 - Start: 456.0, Duration: 2.375, value: half
# 458. 🎵 Note 65 - Start: 457.0, Duration: 0.625, value: quarter
# 459. 🎵 Note 50 - Start: 463.5, Duration: 0.625, value: quarter
# 460. 🎵 Note 74 - Start: 463.5, Duration: 0.625, value: quarter
# 461. 🎵 Note 64 - Start: 464.0, Duration: 1.250, value: tied quarter-sixteenth
# 462. 🎵 Note 69 - Start: 464.5, Duration: 1.250, value: tied quarter-sixteenth
# 463. 🎵 Note 45 - Start: 464.5, Duration: 1.250, value: tied quarter-sixteenth
# 464. 🎵 Note 65 - Start: 466.5, Duration: 0.625, value: quarter
# 465. 🎵 Note 62 - Start: 466.5, Duration: 0.625, value: quarter
# 466. 🎵 Note 73 - Start: 468.5, Duration: 0.625, value: quarter
# 467. 🎵 Note 62 - Start: 470.5, Duration: 1.250, value: tied quarter-sixteenth
# 468. 🎵 Note 50 - Start: 471.5, Duration: 0.625, value: quarter
# 469. 🎵 Note 66 - Start: 471.5, Duration: 0.625, value: quarter
# 470. 🎵 Note 67 - Start: 475.0, Duration: 0.625, value: quarter
# 471. 🎵 Note 61 - Start: 476.0, Duration: 0.625, value: quarter
# 472. 🎵 Note 62 - Start: 478.0, Duration: 0.625, value: quarter
# 473. 🎵 Note 50 - Start: 480.5, Duration: 0.625, value: quarter
# 474. 🎵 Note 74 - Start: 480.5, Duration: 1.750, value: half
# 475. 🎵 Note 86 - Start: 481.0, Duration: 0.625, value: quarter
# 476. 🎵 Note 62 - Start: 483.0, Duration: 0.625, value: quarter
# 477. 🎵 Note 64 - Start: 484.0, Duration: 0.625, value: quarter
# 478. 🎵 Note 67 - Start: 484.0, Duration: 0.625, value: quarter
# 479. 🎵 Note 79 - Start: 484.0, Duration: 0.625, value: quarter
# 480. 🎵 Note 66 - Start: 485.0, Duration: 0.625, value: quarter
# 481. 🎵 Note 71 - Start: 485.5, Duration: 1.250, value: tied quarter-sixteenth
# 482. 🎵 Note 64 - Start: 488.5, Duration: 0.625, value: quarter
# 483. 🎵 Note 83 - Start: 488.5, Duration: 0.625, value: quarter
# 484. 🎵 Note 71 - Start: 490.0, Duration: 0.625, value: quarter
# 485. 🎵 Note 66 - Start: 494.5, Duration: 0.625, value: quarter
# 486. 🎵 Note 62 - Start: 494.5, Duration: 0.625, value: quarter
# 487. 🎵 Note 74 - Start: 496.0, Duration: 0.625, value: quarter
# 488. 🎵 Note 67 - Start: 496.0, Duration: 0.625, value: quarter
# 489. 🎵 Note 57 - Start: 496.5, Duration: 0.625, value: quarter
# 490. 🎵 Note 62 - Start: 497.5, Duration: 0.625, value: quarter
# 491. 🎵 Note 62 - Start: 499.0, Duration: 0.625, value: quarter
# 492. 🎵 Note 74 - Start: 500.0, Duration: 0.625, value: quarter
# 493. 🎵 Note 66 - Start: 502.5, Duration: 0.625, value: quarter
# 494. 🎵 Note 67 - Start: 503.0, Duration: 0.625, value: quarter
# 495. 🎵 Note 69 - Start: 504.5, Duration: 0.625, value: quarter
# 496. 🎵 Note 67 - Start: 507.0, Duration: 0.625, value: quarter
# 497. 🎵 Note 62 - Start: 509.5, Duration: 1.750, value: half
# 498. 🎵 Note 55 - Start: 510.0, Duration: 1.250, value: tied quarter-sixteenth
# 499. 🎵 Note 59 - Start: 510.0, Duration: 2.375, value: half
# 500. 🎵 Note 67 - Start: 510.5, Duration: 0.625, value: quarter
# 501. 🎵 Note 65 - Start: 513.0, Duration: 0.625, value: quarter
# 502. 🎵 Note 62 - Start: 514.5, Duration: 1.250, value: tied quarter-sixteenth
# 503. 🎵 Note 62 - Start: 517.5, Duration: 0.625, value: quarter
# 504. 🎵 Note 62 - Start: 519.5, Duration: 0.625, value: quarter
# 505. 🎵 Note 74 - Start: 521.0, Duration: 0.625, value: quarter
# 506. 🎵 Note 62 - Start: 521.0, Duration: 0.625, value: quarter
# 507. 🎵 Note 58 - Start: 521.5, Duration: 0.625, value: quarter
# 508. 🎵 Note 62 - Start: 522.5, Duration: 0.625, value: quarter
# 509. 🎵 Note 74 - Start: 525.0, Duration: 1.250, value: tied quarter-sixteenth
# 510. 🎵 Note 62 - Start: 526.5, Duration: 1.250, value: tied quarter-sixteenth
# 511. 🎵 Note 83 - Start: 533.5, Duration: 0.625, value: quarter
# 512. 🎵 Note 59 - Start: 533.5, Duration: 0.625, value: quarter
# 513. 🎵 Note 55 - Start: 533.5, Duration: 1.250, value: tied quarter-sixteenth
# 514. 🎵 Note 67 - Start: 534.0, Duration: 0.625, value: quarter
# 515. 🎵 Note 57 - Start: 535.0, Duration: 2.375, value: half
# 516. 🎵 Note 64 - Start: 536.5, Duration: 0.625, value: quarter
# 517. 🎵 Note 73 - Start: 536.5, Duration: 0.625, value: quarter
# 518. 🎵 Note 66 - Start: 537.0, Duration: 0.625, value: quarter
# 519. 🎵 Note 62 - Start: 537.0, Duration: 0.625, value: quarter
# 520. 🎵 Note 45 - Start: 537.5, Duration: 0.625, value: quarter
# 521. 🎵 Note 66 - Start: 540.5, Duration: 0.625, value: quarter
# 522. 🎵 Note 66 - Start: 545.5, Duration: 0.625, value: quarter
# 523. 🎵 Note 69 - Start: 545.5, Duration: 1.250, value: tied quarter-sixteenth
# 524. 🎵 Note 81 - Start: 546.0, Duration: 0.625, value: quarter
# 525. 🎵 Note 66 - Start: 546.5, Duration: 1.250, value: tied quarter-sixteenth
# 526. 🎵 Note 78 - Start: 547.0, Duration: 0.625, value: quarter

# %%
import json

tempo, pulse = get_tempo_pulse("../Data/MusicNet_Dataset/musicnet/musicnet/test_data/1819.wav")
notes_beat = process_notes_sum(notes, tempo)
musicxml_score = convert_to_musicxml(notes_beat, tempo, pulse)
musicxml_score.show()
musicxml_score.write("musicxml", "output.xml")
# Out:
# ---------------------------------------------------------------------------
# SubConverterException                     Traceback (most recent call last)
# Cell In[6], line 4
#       2 notes_beat = process_notes_solo(notes, tempo)
#       3 musicxml_score = convert_to_musicxml(notes_beat, tempo, pulse)
# ----> 4 musicxml_score.show()
#       5 musicxml_score.write("musicxml", "output.xml")
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/music21/stream/base.py:412, in Stream.show(self, fmt, app, **keywords)
#     410 if self.isSorted is False and self.autoSort:
#     411     self.sort()
# --> 412 return super().show(fmt=fmt, app=app, **keywords)
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/music21/base.py:2996, in Music21Object.show(self, fmt, app, **keywords)
#    2994 scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2995 formatWriter = scClass()
# -> 2996 return formatWriter.show(self,
#    2997                          regularizedConverterFormat,
#    2998                          app=app,
#    2999                          subformats=subformats,
#    3000                          **keywords)
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/music21/converter/subConverters.py:383, in ConverterIPython.show(self, obj, fmt, app, subformats, **keywords)
#     380 helperSubConverter = Converter.getSubConverterFromFormat(helperFormat)
#     382 if helperFormat in ('musicxml', 'xml', 'lilypond', 'lily'):
# --> 383     ip21_converters.showImageThroughMuseScore(
#     384         obj,
#     385         subConverter=helperSubConverter,
#     386         fmt=helperFormat,
#     387         subformats=helperSubformats,
#     388         **keywords,
#     389     )
#     390 elif helperFormat == 'midi':
#     391     if t.TYPE_CHECKING:
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/music21/ipython21/converters.py:80, in showImageThroughMuseScore(obj, subConverter, fmt, subformats, multipageWidget, **keywords)
#      70         showImageThroughMuseScore(
#      71             s,
#      72             subConverter=subConverter,
#    (...)
#      76             **keywords,
#      77         )
#      78     return
# ---> 80 fp = subConverter.write(
#      81     obj,
#      82     fmt,
#      83     subformats=subformats,
#      84     trimEdges=not multipageWidget,
#      85     **keywords,
#      86 )
#      88 if subformats[0] != 'png':
#      89     return
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/music21/converter/subConverters.py:991, in ConverterMusicXML.write(self, obj, fmt, fp, subformats, makeNotation, compress, **keywords)
#     988 if (('png' in subformats or 'pdf' in subformats)
#     989         and not str(environLocal['musescoreDirectPNGPath']).startswith('/skip')):
#     990     from music21.converter.museScore import runThroughMuseScore
# --> 991     outFp = runThroughMuseScore(xmlFp, subformats, **keywords)
#     992 elif compress:
#     993     archiveTools.compressXML(xmlFp,
#     994                              deleteOriginal=True,
#     995                              silent=True,
#     996                              strictMxlCheck=False)
#
# File /opt/anaconda3/envs/ndyduc/lib/python3.12/site-packages/music21/converter/museScore.py:55, in runThroughMuseScore(fp, subformats, dpi, trimEdges, leaveMargin, **keywords)
#      51     raise SubConverterException(
#      52         'To create PNG files directly from MusicXML you need to download MuseScore and '
#      53         + 'put a link to it in your .music21rc via Environment.')
#      54 if not museScorePath.exists():
# ---> 55     raise SubConverterException(
#      56         "Cannot find a path to the 'mscore' file at "
#      57         + f'{museScorePath} -- download MuseScore')
#      59 if not subformats:
#      60     subformatExtension = 'png'
#
# SubConverterException: Cannot find a path to the 'mscore' file at /Applications/MuseScore 3.app/Contents/MacOS/mscore -- download MuseScore

# %%
import soundfile as sf

print(sf.available_formats())
# Out:
# {'AIFF': 'AIFF (Apple/SGI)', 'AU': 'AU (Sun/NeXT)', 'AVR': 'AVR (Audio Visual Research)', 'CAF': 'CAF (Apple Core Audio File)', 'FLAC': 'FLAC (Free Lossless Audio Codec)', 'HTK': 'HTK (HMM Tool Kit)', 'SVX': 'IFF (Amiga IFF/SVX8/SV16)', 'MAT4': 'MAT4 (GNU Octave 2.0 / Matlab 4.2)', 'MAT5': 'MAT5 (GNU Octave 2.1 / Matlab 5.0)', 'MPC2K': 'MPC (Akai MPC 2k)', 'MP3': 'MPEG-1/2 Audio', 'OGG': 'OGG (OGG Container format)', 'PAF': 'PAF (Ensoniq PARIS)', 'PVF': 'PVF (Portable Voice Format)', 'RAW': 'RAW (header-less)', 'RF64': 'RF64 (RIFF 64)', 'SD2': 'SD2 (Sound Designer II)', 'SDS': 'SDS (Midi Sample Dump Standard)', 'IRCAM': 'SF (Berkeley/IRCAM/CARL)', 'VOC': 'VOC (Creative Labs)', 'W64': 'W64 (SoundFoundry WAVE 64)', 'WAV': 'WAV (Microsoft)', 'NIST': 'WAV (NIST Sphere)', 'WAVEX': 'WAVEX (Microsoft)', 'WVE': 'WVE (Psion Series 3)', 'XI': 'XI (FastTracker 2)'}
