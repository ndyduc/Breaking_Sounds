# %%
import glob
import random
import os
import torch
import torch.optim as optim
import time
from Model.BiLSTM import *

shuffle_file = "../Trained/schuffle.txt"

wav_files, csv_files = [], []

# Tạo model & optimizer
model = BiLSTM().to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# Load trạng thái đã lưu nếu có
checkpoint_path = "../Trained/LSTM_full.pth"
if os.path.exists(checkpoint_path):
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint["model_state"])
    optimizer.load_state_dict(checkpoint["optimizer_state"])
    last_trained_index = checkpoint["last_trained_index"]
    print(f"Resuming training from file {last_trained_index + 1}/{len(wav_files)}: {wav_files[last_trained_index]}")
else:
    last_trained_index = -1  # Train từ đầu nếu không có checkpoint

# Train trên danh sách file đã shuffle từ điểm dừng
for i, (wav_path, csv_path) in enumerate(zip(wav_files, csv_files)):
    if i <= last_trained_index:
        continue  # Bỏ qua các file đã train

    print(time.strftime("%H:%M:%S"), f"Training on {os.path.basename(wav_path)}")
    train_on_wav(model, optimizer, criterion, wav_path, csv_path, epochs=10)

    # Lưu checkpoint sau mỗi file
    checkpoint = {
        "model_state": model.state_dict(),
        "optimizer_state": optimizer.state_dict(),
        "last_trained_index": i
    }
    torch.save(checkpoint, checkpoint_path)
    print(f"Checkpoint saved at {checkpoint_path}")

print("Training complete!")
# Out:
# Loaded shuffled file list from previous training.
# ...

# %%
import torch

# Load checkpoint
checkpoint_path = "../Trained/BiLSTM.pth"
checkpoint = torch.load(checkpoint_path, map_location=device)

# Chỉ lấy state_dict của model
model_state_dict = checkpoint["model_state"]

# Lưu lại state_dict đúng định dạng
torch.save(model_state_dict, "../Trained/LSTM_basic.pth")

print("Đã trích xuất state_dict và lưu lại vào BiLSTM_state_dict.pth")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_12669/3745883627.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
import os
from Model.BiLSTM import *  # Import model của bạn

# Định nghĩa đường dẫn
state_dict_path = "../Trained/LSTM_lossdown.pth"
wav_file = "../Data/MusicNet_Dataset/musicnet/musicnet/train_data/2243.wav"
csv_file = "../Data/MusicNet_Dataset/musicnet/musicnet/train_labels/2243.csv"

# Khởi tạo model & optimizer
model = BiLSTM().to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# Load model từ state_dict
if os.path.exists(state_dict_path):
    model.load_state_dict(torch.load(state_dict_path, map_location=device))
    print("Model đã load thành công từ state_dict!")

# Train lại trên file 2243.wav
print(f"Training on {os.path.basename(wav_file)}")
train_on_wav(model, optimizer, criterion, wav_file, csv_file, epochs=10)

# Lưu lại model sau khi train
torch.save(model.state_dict(), "../Trained/LSTM_state_dict.pth")
print("Model đã được train xong và lưu lại!")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_12669/3860843386.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
import glob
import os
import numpy as np
import pandas as pd
import librosa
from Model.BiLSTM import *


# Lấy danh sách file train
wav_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_data/*.wav"))
csv_files = sorted(glob.glob("../Data/MusicNet_Dataset/musicnet/musicnet/test_labels/*.csv"))

# Khởi tạo model và load trọng số
state_dict_path = "../Trained/BiLSTM_state_dict.pth"
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

model = BiLSTM().to(device)
model.load_state_dict(torch.load(state_dict_path, map_location=device))
model.eval()  # Chuyển sang chế độ đánh giá

# Hàm tính accuracy
def compute_accuracy(y_true, y_pred):
    y_pred = (y_pred > 0.5).float()  # Chuyển output thành nhị phân (0 hoặc 1)
    correct = (y_pred == y_true).float().sum()
    total = y_true.numel()
    return correct / total

def evaluate_model(model, wav_path, csv_path, batch_size=32):
    X_test, y_notes_true, y_instr_true = load_wav_csv(wav_path, csv_path)

    total_acc_notes = 0
    total_acc_instr = 0
    num_batches = 0

    with torch.no_grad():
        for i in range(0, len(X_test), batch_size):
            X_batch = X_test[i:i+batch_size].to(device)
            y_notes_batch = y_notes_true[i:i+batch_size].to(device)
            y_instr_batch = y_instr_true[i:i+batch_size].to(device)

            y_notes_pred, y_instr_pred = model(X_batch)

            acc_notes = compute_accuracy(y_notes_batch, y_notes_pred)
            acc_instr = compute_accuracy(y_instr_batch, y_instr_pred)

            total_acc_notes += acc_notes.item()
            total_acc_instr += acc_instr.item()
            num_batches += 1

    return (total_acc_notes / num_batches) * 100, (total_acc_instr / num_batches) * 100

# Đánh giá toàn bộ tập train
total_accuracy_notes = 0
total_accuracy_instr = 0
num_samples = 0

for wav_path, csv_path in zip(wav_files, csv_files):
    acc_notes, acc_instr = evaluate_model(model, wav_path, csv_path)
    print(f"File: {os.path.basename(wav_path)} - Notes Accuracy: {acc_notes:.2f}% - Instruments Accuracy: {acc_instr:.2f}%")

    total_accuracy_notes += acc_notes
    total_accuracy_instr += acc_instr
    num_samples += 1

# Tính accuracy trung bình
final_acc_notes = total_accuracy_notes / num_samples
final_acc_instr = total_accuracy_instr / num_samples

print("\n===== Final Train Set Accuracy =====")
print(f"Average Accuracy (Notes): {final_acc_notes:.2f}%")
print(f"Average Accuracy (Instruments): {final_acc_instr:.2f}%")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_24917/3848010972.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# Khởi tạo model và load trọng số
state_dict_path = "../Trained/BiLSTM_lossdown.pth"

model = BiLSTM().to(device)
model.load_state_dict(torch.load(state_dict_path, map_location=device))
model.eval()  # Chuyển sang chế độ đánh giá

# Đánh giá toàn bộ tập train
total_accuracy_notes = 0
total_accuracy_instr = 0
num_samples = 0

for wav_path, csv_path in zip(wav_files, csv_files):
    acc_notes, acc_instr = evaluate_model(model, wav_path, csv_path)
    print(f"File: {os.path.basename(wav_path)} - Notes Accuracy: {acc_notes:.2f}% - Instruments Accuracy: {acc_instr:.2f}%")

    total_accuracy_notes += acc_notes
    total_accuracy_instr += acc_instr
    num_samples += 1

# Tính accuracy trung bình
final_acc_notes = total_accuracy_notes / num_samples
final_acc_instr = total_accuracy_instr / num_samples

print("\n===== Final Train Set Accuracy =====")
print(f"Average Accuracy (Notes): {final_acc_notes:.2f}%")
print(f"Average Accuracy (Instruments): {final_acc_instr:.2f}%")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_12669/3454248187.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# Khởi tạo model và load trọng số
state_dict_path = "../Trained/BiLSTM.pth"

model = BiLSTM().to(device)
model.load_state_dict(torch.load(state_dict_path, map_location=device))
model.eval()  # Chuyển sang chế độ đánh giá

# Đánh giá toàn bộ tập train
total_accuracy_notes = 0
total_accuracy_instr = 0
num_samples = 0

for wav_path, csv_path in zip(wav_files, csv_files):
    acc_notes, acc_instr = evaluate_model(model, wav_path, csv_path)
    print(f"File: {os.path.basename(wav_path)} - Notes Accuracy: {acc_notes:.2f}% - Instruments Accuracy: {acc_instr:.2f}%")

    total_accuracy_notes += acc_notes
    total_accuracy_instr += acc_instr
    num_samples += 1

# Tính accuracy trung bình
final_acc_notes = total_accuracy_notes / num_samples
final_acc_instr = total_accuracy_instr / num_samples

print("\n===== Final Train Set Accuracy =====")
print(f"Average Accuracy (Notes): {final_acc_notes:.2f}%")
print(f"Average Accuracy (Instruments): {final_acc_instr:.2f}%")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_12669/2481217379.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# Khởi tạo model và load trọng số
state_dict_path = "../Trained/BiLSTM_512.pth"

model = BiLSTM().to(device)
model.load_state_dict(torch.load(state_dict_path, map_location=device))
model.eval()  # Chuyển sang chế độ đánh giá

# Đánh giá toàn bộ tập train
total_accuracy_notes = 0
total_accuracy_instr = 0
num_samples = 0

for wav_path, csv_path in zip(wav_files, csv_files):
    acc_notes, acc_instr = evaluate_model(model, wav_path, csv_path)
    print(f"File: {os.path.basename(wav_path)} - Notes Accuracy: {acc_notes:.2f}% - Instruments Accuracy: {acc_instr:.2f}%")

    total_accuracy_notes += acc_notes
    total_accuracy_instr += acc_instr
    num_samples += 1

# Tính accuracy trung bình
final_acc_notes = total_accuracy_notes / num_samples
final_acc_instr = total_accuracy_instr / num_samples

print("\n===== Final Train Set Accuracy =====")
print(f"Average Accuracy (Notes): {final_acc_notes:.2f}%")
print(f"Average Accuracy (Instruments): {final_acc_instr:.2f}%")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_12669/1334617263.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
import glob
import os
from Model.BiLSTM import *

# Load model
checkpoint_path = "../Trained/BiLSTM_full.pth"
model = BiLSTM().to(device)

if os.path.exists(checkpoint_path):
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint['model_state'])
    print("Model loaded from checkpoint.")
else:
    raise FileNotFoundError("Checkpoint file not found!")

model.eval()  # Chuyển sang chế độ đánh giá


# Đánh giá trên tập train
total_acc_notes = 0
total_acc_instr = 0
total_samples = 0

def evaluate_model(model, wav_path, csv_path, batch_size=32):
    inputs, y_notes_true, y_instr_true = load_wav_csv(wav_path, csv_path)
    
    total_acc_notes, total_acc_instr = 0, 0
    total_batches = (len(inputs) + batch_size - 1) // batch_size  # Tính số batch

    with torch.no_grad():
        for i in range(0, len(inputs), batch_size):
            batch_inputs = inputs[i:i+batch_size].to(device)
            batch_y_notes_true = y_notes_true[i:i+batch_size].to(device)
            batch_y_instr_true = y_instr_true[i:i+batch_size].to(device)

            y_notes_pred, y_instr_pred = model(batch_inputs)

            acc_notes = compute_accuracy(batch_y_notes_true, y_notes_pred)
            acc_instr = compute_accuracy(batch_y_instr_true, y_instr_pred)

            total_acc_notes += acc_notes
            total_acc_instr += acc_instr

    return (total_acc_notes / total_batches), (total_acc_instr / total_batches) # Trả về % chính xác

for wav_path, csv_path in zip(wav_files, csv_files):
    acc_notes, acc_instr = evaluate_model(model, wav_path, csv_path)
    print(f"Accuracy on {os.path.basename(wav_path)} - Notes: {acc_notes:.2f}%, Instruments: {acc_instr:.2f}%")

    total_acc_notes += acc_notes
    total_acc_instr += acc_instr
    total_samples += 1

# In tổng accuracy trung bình
final_acc_notes = total_acc_notes / total_samples
final_acc_instr = total_acc_instr / total_samples
print(f"\nFinal Train Set Accuracy - Notes: {final_acc_notes:.2f}%, Instruments: {final_acc_instr:.2f}%")
# Out:
# /var/folders/fr/m00k3ffd001fy8ptw38pn78h0000gn/T/ipykernel_24917/3108965537.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
